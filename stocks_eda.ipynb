# %% [markdown]
# <h3>Visualization of data from combined_data_stock.json from Database</h3>

# %%
# !pip install mplfinance

# %%
import pandas as pd
import matplotlib.pyplot as plt
import mplfinance as mpf

# %%
# dataframe with stocks data
df_stocks = pd.read_json('./Database/combined_data_stock.json', lines=True)
df_stocks['begin'] = pd.to_datetime(df_stocks['begin'])

df_stocks
# Out:
#            begin     open    close     high      low         value  volume  \
# 0     2020-03-10    479.7    484.5    499.8    479.4  9.199434e+07  189180
# 1     2020-03-11    484.2    485.0    495.8    481.7  3.756703e+07   76870
# 2     2020-03-12    470.2    490.0    490.0    412.5  1.065080e+08  238920
# 3     2020-03-13    485.0    465.0    487.9    460.2  6.449649e+07  136230
# 4     2020-03-16    472.0    440.5    472.0    425.4  1.058595e+08  238000
# ...          ...      ...      ...      ...      ...           ...     ...
# 47457 2025-03-04  19195.0  19702.5  19800.0  19092.0  4.789262e+09  245609
# 47458 2025-03-05  19750.0  19531.5  19846.5  19412.0  4.573746e+09  233507
# 47459 2025-03-06  19557.0  19550.0  19875.0  19428.5  3.019816e+09  153555
# 47460 2025-03-07  19451.0  19399.5  19670.0  19074.5  3.047559e+09  157184
# 47461 2025-03-10  19450.0  19050.0  19600.0  19029.0  4.631204e+09  240259
#
#       STOCK_TICK
# 0           MVID
# 1           MVID
# ...

# %% [markdown]
# <h4>Visualization of the data of the particular company (with ticker RNFT) as an example</h4>

# %%
# choosing the necessary ticker
ticker1 = 'RNFT'
filtered_data1 = df_stocks[df_stocks['STOCK_TICK'] == ticker1]
fig, axs = plt.subplots(3, 2, figsize=(20, 10))

# plotting graph of open prices
axs[0, 0].plot(filtered_data1['begin'], filtered_data1['open'], color='blue')
axs[0, 0].set_title('Open Prices')
axs[0, 0].set_xlabel('Date')
axs[0, 0].set_ylabel('Price')
axs[0, 0].grid()

# plotting graph of close prices
axs[0, 1].plot(filtered_data1['begin'], filtered_data1['close'], color='green')
axs[0, 1].set_title('Close Prices')
axs[0, 1].set_xlabel('Date')
axs[0, 1].set_ylabel('Price')
axs[0, 1].grid()

# plotting graph of low prices
filtered_data1['low'] = filtered_data1['high']
axs[1, 0].plot(filtered_data1['begin'], filtered_data1['low'], color='orange')
axs[1, 0].set_title('Low Prices')
axs[1, 0].set_xlabel('Date')
axs[1, 0].set_ylabel('Price')
axs[1, 0].grid()

# plotting graph of high prices
axs[1, 1].plot(filtered_data1['begin'], filtered_data1['high'], color='red')
axs[1, 1].set_title('High Prices')
axs[1, 1].set_xlabel('Date')
axs[1, 1].set_ylabel('Price')
axs[1, 1].grid()

# plotting graph of values
axs[2, 0].plot(filtered_data1['begin'], filtered_data1['value'], color='purple')
axs[2, 0].set_title('Values')
axs[2, 0].set_xlabel('Date')
axs[2, 0].set_ylabel('Price')
axs[2, 0].grid()

# plotting graph of volumes
axs[2, 1].plot(filtered_data1['begin'], filtered_data1['volume'], color='magenta')
axs[2, 1].set_title('Volumes')
axs[2, 1].set_xlabel('Date')
axs[2, 1].set_ylabel('Number of shares')
axs[2, 1].grid()

fig.suptitle(f"Information about {ticker1} stocks")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_6811/3532737469.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data1['low'] = filtered_data1['high']

# %% [markdown]
# <h4>Visualization of the data of the particular company (with ticker SBER) as an example</h4>

# %%
# choosing the necessary ticker
ticker2 = 'SBER'
filtered_data2 = df_stocks[df_stocks['STOCK_TICK'] == ticker2]
fig, axs = plt.subplots(3, 2, figsize=(20, 10))

# plotting graph of open prices
axs[0, 0].plot(filtered_data2['begin'], filtered_data2['open'], color='blue')
axs[0, 0].set_title('Open Prices')
axs[0, 0].set_xlabel('Date')
axs[0, 0].set_ylabel('Price')
axs[0, 0].grid()

# plotting graph of close prices
axs[0, 1].plot(filtered_data2['begin'], filtered_data2['close'], color='green')
axs[0, 1].set_title('Close Prices')
axs[0, 1].set_xlabel('Date')
axs[0, 1].set_ylabel('Price')
axs[0, 1].grid()

# plotting graph of low prices
filtered_data2['low'] = filtered_data2['high']
axs[1, 0].plot(filtered_data2['begin'], filtered_data2['low'], color='orange')
axs[1, 0].set_title('Low Prices')
axs[1, 0].set_xlabel('Date')
axs[1, 0].set_ylabel('Price')
axs[1, 0].grid()

# plotting graph of high prices
axs[1, 1].plot(filtered_data2['begin'], filtered_data2['high'], color='red')
axs[1, 1].set_title('High Prices')
axs[1, 1].set_xlabel('Date')
axs[1, 1].set_ylabel('Price')
axs[1, 1].grid()

# plotting graph of values
axs[2, 0].plot(filtered_data2['begin'], filtered_data2['value'], color='purple')
axs[2, 0].set_title('Values')
axs[2, 0].set_xlabel('Date')
axs[2, 0].set_ylabel('Price')
axs[2, 0].grid()

# plotting graph of volumes
axs[2, 1].plot(filtered_data2['begin'], filtered_data2['volume'], color='magenta')
axs[2, 1].set_title('Volumes')
axs[2, 1].set_xlabel('Date')
axs[2, 1].set_ylabel('Number of shares')
axs[2, 1].grid()

fig.suptitle(f"Information about {ticker2} stocks")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_6811/4215419601.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data2['low'] = filtered_data2['high']

# %% [markdown]
# <h4>Candlestick graphs for the RNFT data</h4>
#
#
# Here, green means that the closing price was higher than the opening price; red means the opposite.

# %%
# setting the column "begin" as index in RNFT ticker dataframe
filtered_data1.set_index('begin', inplace=True)

# %%
# selecting monthly data of RNFT
monthly_data = filtered_data1.resample('M').agg({
    'open': 'first',
    'high': 'max',
    'low': 'min',
    'close': 'last',
    'volume': 'sum'
})

# plotting the chart
mpf.plot(
    monthly_data,
    type='candle',
    title=f'Monthly Candlestick Chart for {ticker1}',
    style='charles',
    figsize=(14, 7) 
)
# Out:
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_6811/1587983248.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_data = filtered_data1.resample('M').agg({

# %%
# selecting yearly data of RNFT
yearly_data = filtered_data1.resample('Y').agg({
    'open': 'first',
    'high': 'max',
    'low': 'min',
    'close': 'last',
    'volume': 'sum'
})

# plotting the chart
mpf.plot(
    yearly_data,
    type='candle',
    title=f'Yearly Candlestick Chart for {ticker1}',
    style='charles',
    figsize=(14, 7) 
)
# Out:
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_6811/4194151492.py:2: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   yearly_data = filtered_data1.resample('Y').agg({

# %% [markdown]
# <h4>Candlestick graphs for the SBER data</h4>
#
#
# Here, green means that the closing price was higher than the opening price; red means the opposite.

# %%
# setting the column "begin" as index in SBER ticker dataframe
filtered_data2.set_index('begin', inplace=True)

# %%
# selecting monthly data of SBER
monthly_data2 = filtered_data2.resample('M').agg({
    'open': 'first',
    'high': 'max',
    'low': 'min',
    'close': 'last',
    'volume': 'sum'
})

# plotting the chart
mpf.plot(
    monthly_data2,
    type='candle',
    title=f'Monthly Candlestick Chart for {ticker2}',
    style='charles',
    figsize=(14, 7) 
)
# Out:
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_6811/1306277541.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_data2 = filtered_data2.resample('M').agg({

# %%
# selecting yearly data of SBER
yearly_data2 = filtered_data2.resample('Y').agg({
    'open': 'first',
    'high': 'max',
    'low': 'min',
    'close': 'last',
    'volume': 'sum'
})

# plotting the chart
mpf.plot(
    yearly_data2,
    type='candle',
    title=f'Yearly Candlestick Chart for {ticker2}',
    style='charles',
    figsize=(14, 7) 
)
# Out:
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_6811/3616989033.py:2: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   yearly_data2 = filtered_data2.resample('Y').agg({

# %% [markdown]
# <h4>Comparison between the companies</h4>

# %%
# dataframe with mean of values for different companies
mean_values = df_stocks.groupby('STOCK_TICK')['value'].mean().reset_index()

# plotting the graph
plt.figure(figsize=(10, 6))
plt.bar(mean_values['STOCK_TICK'], mean_values['value'], color='purple')
plt.title('Mean Value of Different Companies')
plt.xlabel('Company Ticker')
plt.ylabel('Mean Value (₽)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# dataframe with mean of volumes for different companies
mean_values = df_stocks.groupby('STOCK_TICK')['volume'].mean().reset_index()

# plotting the graph
plt.figure(figsize=(10, 6))
plt.bar(mean_values['STOCK_TICK'], mean_values['volume'], color='magenta')
plt.title('Mean Volume of Different Companies')
plt.ylabel('Mean Volume')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# dataframe with mean of open prices for different companies
mean_values = df_stocks.groupby('STOCK_TICK')['open'].mean().reset_index()

# plotting the graph
plt.figure(figsize=(10, 6))
plt.bar(mean_values['STOCK_TICK'], mean_values['open'], color='blue')
plt.title('Mean Open Price of Different Companies')
plt.ylabel('Mean Open Price (₽)')
plt.xlabel('Company Ticker')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# dataframe with mean of close prices for different companies
mean_values = df_stocks.groupby('STOCK_TICK')['close'].mean().reset_index()

# plotting the graph
plt.figure(figsize=(10, 6))
plt.bar(mean_values['STOCK_TICK'], mean_values['close'], color='green')
plt.title('Mean Close Price of Different Companies')
plt.ylabel('Mean Close Price (₽)')
plt.xlabel('Company Ticker')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# dataframe with mean of low prices for different companies
mean_values = df_stocks.groupby('STOCK_TICK')['low'].mean().reset_index()

# plotting the graph
plt.figure(figsize=(10, 6))
plt.bar(mean_values['STOCK_TICK'], mean_values['low'], color='orange')
plt.title('Mean Low Price of Different Companies')
plt.ylabel('Mean Low Price (₽)')
plt.xlabel('Company Ticker')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# dataframe with mean of high prices for different companies
mean_values = df_stocks.groupby('STOCK_TICK')['high'].mean().reset_index()

# plotting the graph
plt.figure(figsize=(10, 6))
plt.bar(mean_values['STOCK_TICK'], mean_values['high'], color='red')
plt.title('Mean High Price of Different Companies')
plt.ylabel('Mean High Price (₽)')
plt.xlabel('Company Ticker')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
