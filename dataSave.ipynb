# %% [markdown]
# <h3><b>Installing and importing necessary libraries</b></h3>

# %%
# !pip install requests
# !pip install apimoex
# !pip install pandas
# Out:
# Requirement already satisfied: requests in ./.venv/lib/python3.13/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.13/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.13/site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.13/site-packages (from requests) (2025.1.31)
# Requirement already satisfied: apimoex in ./.venv/lib/python3.13/site-packages (1.4.0)
# Requirement already satisfied: requests>=2.31.0 in ./.venv/lib/python3.13/site-packages (from apimoex) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests>=2.31.0->apimoex) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.13/site-packages (from requests>=2.31.0->apimoex) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.13/site-packages (from requests>=2.31.0->apimoex) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.13/site-packages (from requests>=2.31.0->apimoex) (2025.1.31)
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.13/site-packages (from pandas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import requests
import apimoex
from datetime import datetime
import pandas as pd
import pathlib
import xml.etree.ElementTree as ET

# %% [markdown]
# <h3><b>Parsing of candle data for stocks and indexes</b></h3>

# %%
# opening the txt files with the ticker names of necessary companies
with open("TICK_DIV.txt", "r") as TICKs_file:
    TICKs = [line.rstrip() for line in TICKs_file]

with open("TICK_IND.txt", "r") as TICK2s_file:
    TICK2s = [line.rstrip() for line in TICK2s_file]

pathlib.Path("Database").mkdir(parents=True, exist_ok=True)

# empty lists to collect DataFrames
all_data_frames = []
all_data_frames_index = []

# additional info for parsing
end_date = datetime.now()
day = end_date.day
month = end_date.month
process = 0
process2 = 0

# parsing process of candles info
with requests.Session() as session:
    # parsing process of candles info (for stocks)
    for i in range(0, len(TICKs)):
        process += 1
        print(f"Parsing candle data for the necessary tickers {(process / len(TICKs)) * 100} %")

        # parsing stocks data for the ticker
        data = apimoex.get_market_candles(session, TICKs[i], start=f"2020-{month}-{day}", end=f"2025-{month}-{day}")
        if not data:  # skiping if there is no data for the ticker
            continue

        # creating a DataFrame from the candles data (of stocks)
        df = pd.DataFrame(data)
        # adding a new column for the STOCK_TICK and period values
        df['STOCK_TICK'] = TICKs[i]
        df['period'] = 'D'

        # appending the DataFrame to the list
        all_data_frames.append(df)
    
    # parsing process of candles info (for indexes)
    for i in range(0, len(TICK2s)):
        process2 += 1
        print(f"Parsing index data for the necessary tickers {(process2 / len(TICK2s)) * 100} %")

        # parsing indexes data for the ticker
        data_index = apimoex.get_market_candles(session, TICK2s[i], start=f"2020-{month}-{day}", end=f"2025-{month}-{day}", market="index")
        if not data_index:  # skiping if there is no data for the ticker
            continue
        
        # parsing of data about what's inside an index (which tickers)
        p3 = 0
        for di in data_index:
            p3 += 1
            print(f'For {TICK2s[i]} ticker parsing. Currently parsed: {p3/len(data_index) * 100} %')
            di['tickers'] = set()
            data_index_tick = apimoex.get_index_tickers(session, TICK2s[i], di['begin'])
            for dit in data_index_tick:
                di['tickers'].add(dit['ticker'])

        # crearing a DataFrame from the candles data (of indexes)
        df_index = pd.DataFrame(data_index)
        # adding a new column for the INDEX_TICK and perion values
        df_index['INDEX_TICK'] = TICK2s[i]
        df_index['period'] = 'D'
        # dropping unnecessary columns
        df_index = df_index.drop(columns=['volume'])
        # appending the DataFrame to the list
        all_data_frames_index.append(df_index)

# concatenating all the collected DataFrames into one (for stocks info)
combined_data = pd.concat(all_data_frames, ignore_index=True) 
# saving the combined DataFrame to a single JSON file (for stocks info)
combined_data.to_json("Database/combined_data_stock.json", orient='records', lines=True)

# concatenating all the collected DataFrames into one (for indexes info)
combined_data_index = pd.concat(all_data_frames_index, ignore_index=True)
# Save the combined DataFrame to a single JSON file (for indexes info)
combined_data_index.to_json("Database/combined_data_index.json", orient='records', lines=True)
# Out:
# Parsing candle data for the necessary tickers 2.631578947368421 %
# Parsing candle data for the necessary tickers 5.263157894736842 %
# Parsing candle data for the necessary tickers 7.894736842105263 %
# Parsing candle data for the necessary tickers 10.526315789473683 %
# Parsing candle data for the necessary tickers 13.157894736842104 %
# Parsing candle data for the necessary tickers 15.789473684210526 %
# Parsing candle data for the necessary tickers 18.421052631578945 %
# Parsing candle data for the necessary tickers 21.052631578947366 %
# Parsing candle data for the necessary tickers 23.684210526315788 %
# Parsing candle data for the necessary tickers 26.31578947368421 %
# Parsing candle data for the necessary tickers 28.947368421052634 %
# Parsing candle data for the necessary tickers 31.57894736842105 %
# Parsing candle data for the necessary tickers 34.21052631578947 %
# Parsing candle data for the necessary tickers 36.84210526315789 %
# Parsing candle data for the necessary tickers 39.473684210526315 %
# Parsing candle data for the necessary tickers 42.10526315789473 %
# Parsing candle data for the necessary tickers 44.73684210526316 %
# Parsing candle data for the necessary tickers 47.368421052631575 %
# Parsing candle data for the necessary tickers 50.0 %
# Parsing candle data for the necessary tickers 52.63157894736842 %
# Parsing candle data for the necessary tickers 55.26315789473685 %
# Parsing candle data for the necessary tickers 57.89473684210527 %
# Parsing candle data for the necessary tickers 60.526315789473685 %
# Parsing candle data for the necessary tickers 63.1578947368421 %
# Parsing candle data for the necessary tickers 65.78947368421053 %
# Parsing candle data for the necessary tickers 68.42105263157895 %
# Parsing candle data for the necessary tickers 71.05263157894737 %
# Parsing candle data for the necessary tickers 73.68421052631578 %
# Parsing candle data for the necessary tickers 76.31578947368422 %
# Parsing candle data for the necessary tickers 78.94736842105263 %
# Parsing candle data for the necessary tickers 81.57894736842105 %
# Parsing candle data for the necessary tickers 84.21052631578947 %
# Parsing candle data for the necessary tickers 86.8421052631579 %
# Parsing candle data for the necessary tickers 89.47368421052632 %
# Parsing candle data for the necessary tickers 92.10526315789474 %
# Parsing candle data for the necessary tickers 94.73684210526315 %
# Parsing candle data for the necessary tickers 97.36842105263158 %
# Parsing candle data for the necessary tickers 100.0 %
# Parsing index data for the necessary tickers 10.0 %
# For IMOEX ticker parsing. Currently parsed: 0.07987220447284345 %
# For IMOEX ticker parsing. Currently parsed: 0.1597444089456869 %
# For IMOEX ticker parsing. Currently parsed: 0.23961661341853036 %
# For IMOEX ticker parsing. Currently parsed: 0.3194888178913738 %
# For IMOEX ticker parsing. Currently parsed: 0.3993610223642172 %
# For IMOEX ticker parsing. Currently parsed: 0.4792332268370607 %
# For IMOEX ticker parsing. Currently parsed: 0.5591054313099041 %
# For IMOEX ticker parsing. Currently parsed: 0.6389776357827476 %
# For IMOEX ticker parsing. Currently parsed: 0.7188498402555911 %
# For IMOEX ticker parsing. Currently parsed: 0.7987220447284344 %
# For IMOEX ticker parsing. Currently parsed: 0.8785942492012779 %
# For IMOEX ticker parsing. Currently parsed: 0.9584664536741214 %
# For IMOEX ticker parsing. Currently parsed: 1.038338658146965 %
# For IMOEX ticker parsing. Currently parsed: 1.1182108626198082 %
# For IMOEX ticker parsing. Currently parsed: 1.1980830670926517 %
# For IMOEX ticker parsing. Currently parsed: 1.2779552715654952 %
# For IMOEX ticker parsing. Currently parsed: 1.3578274760383386 %
# For IMOEX ticker parsing. Currently parsed: 1.4376996805111821 %
# For IMOEX ticker parsing. Currently parsed: 1.5175718849840254 %
# For IMOEX ticker parsing. Currently parsed: 1.5974440894568689 %
# For IMOEX ticker parsing. Currently parsed: 1.6773162939297124 %
# For IMOEX ticker parsing. Currently parsed: 1.7571884984025559 %
# For IMOEX ticker parsing. Currently parsed: 1.8370607028753994 %
# For IMOEX ticker parsing. Currently parsed: 1.9169329073482428 %
# For IMOEX ticker parsing. Currently parsed: 1.996805111821086 %
# For IMOEX ticker parsing. Currently parsed: 2.07667731629393 %
# For IMOEX ticker parsing. Currently parsed: 2.156549520766773 %
# For IMOEX ticker parsing. Currently parsed: 2.2364217252396164 %
# For IMOEX ticker parsing. Currently parsed: 2.31629392971246 %
# For IMOEX ticker parsing. Currently parsed: 2.3961661341853033 %
# For IMOEX ticker parsing. Currently parsed: 2.476038338658147 %
# For IMOEX ticker parsing. Currently parsed: 2.5559105431309903 %
# For IMOEX ticker parsing. Currently parsed: 2.635782747603834 %
# For IMOEX ticker parsing. Currently parsed: 2.7156549520766773 %
# For IMOEX ticker parsing. Currently parsed: 2.7955271565495208 %
# For IMOEX ticker parsing. Currently parsed: 2.8753993610223643 %
# For IMOEX ticker parsing. Currently parsed: 2.9552715654952078 %
# For IMOEX ticker parsing. Currently parsed: 3.035143769968051 %
# For IMOEX ticker parsing. Currently parsed: 3.1150159744408943 %
# For IMOEX ticker parsing. Currently parsed: 3.1948881789137378 %
# For IMOEX ticker parsing. Currently parsed: 3.2747603833865817 %
# For IMOEX ticker parsing. Currently parsed: 3.3546325878594248 %
# For IMOEX ticker parsing. Currently parsed: 3.4345047923322687 %
# For IMOEX ticker parsing. Currently parsed: 3.5143769968051117 %
# For IMOEX ticker parsing. Currently parsed: 3.5942492012779557 %
# For IMOEX ticker parsing. Currently parsed: 3.6741214057507987 %
# For IMOEX ticker parsing. Currently parsed: 3.753993610223642 %
# For IMOEX ticker parsing. Currently parsed: 3.8338658146964857 %
# For IMOEX ticker parsing. Currently parsed: 3.913738019169329 %
# For IMOEX ticker parsing. Currently parsed: 3.993610223642172 %
# For IMOEX ticker parsing. Currently parsed: 4.073482428115016 %
# For IMOEX ticker parsing. Currently parsed: 4.15335463258786 %
# For IMOEX ticker parsing. Currently parsed: 4.233226837060703 %
# For IMOEX ticker parsing. Currently parsed: 4.313099041533546 %
# For IMOEX ticker parsing. Currently parsed: 4.39297124600639 %
# For IMOEX ticker parsing. Currently parsed: 4.472843450479233 %
# For IMOEX ticker parsing. Currently parsed: 4.552715654952077 %
# For IMOEX ticker parsing. Currently parsed: 4.63258785942492 %
# For IMOEX ticker parsing. Currently parsed: 4.712460063897764 %
# For IMOEX ticker parsing. Currently parsed: 4.792332268370607 %
# For IMOEX ticker parsing. Currently parsed: 4.872204472843451 %
# For IMOEX ticker parsing. Currently parsed: 4.952076677316294 %
# For IMOEX ticker parsing. Currently parsed: 5.031948881789138 %
# For IMOEX ticker parsing. Currently parsed: 5.111821086261981 %
# For IMOEX ticker parsing. Currently parsed: 5.1916932907348246 %
# For IMOEX ticker parsing. Currently parsed: 5.271565495207668 %
# For IMOEX ticker parsing. Currently parsed: 5.3514376996805115 %
# For IMOEX ticker parsing. Currently parsed: 5.431309904153355 %
# For IMOEX ticker parsing. Currently parsed: 5.5111821086261985 %
# For IMOEX ticker parsing. Currently parsed: 5.5910543130990416 %
# For IMOEX ticker parsing. Currently parsed: 5.6709265175718855 %
# For IMOEX ticker parsing. Currently parsed: 5.7507987220447285 %
# For IMOEX ticker parsing. Currently parsed: 5.830670926517572 %
# For IMOEX ticker parsing. Currently parsed: 5.9105431309904155 %
# For IMOEX ticker parsing. Currently parsed: 5.9904153354632586 %
# For IMOEX ticker parsing. Currently parsed: 6.070287539936102 %
# For IMOEX ticker parsing. Currently parsed: 6.1501597444089455 %
# For IMOEX ticker parsing. Currently parsed: 6.230031948881789 %
# For IMOEX ticker parsing. Currently parsed: 6.3099041533546325 %
# For IMOEX ticker parsing. Currently parsed: 6.3897763578274756 %
# For IMOEX ticker parsing. Currently parsed: 6.469648562300319 %
# For IMOEX ticker parsing. Currently parsed: 6.549520766773163 %
# For IMOEX ticker parsing. Currently parsed: 6.6293929712460065 %
# For IMOEX ticker parsing. Currently parsed: 6.7092651757188495 %
# For IMOEX ticker parsing. Currently parsed: 6.7891373801916926 %
# For IMOEX ticker parsing. Currently parsed: 6.869009584664537 %
# For IMOEX ticker parsing. Currently parsed: 6.94888178913738 %
# For IMOEX ticker parsing. Currently parsed: 7.0287539936102235 %
# For IMOEX ticker parsing. Currently parsed: 7.1086261980830665 %
# For IMOEX ticker parsing. Currently parsed: 7.188498402555911 %
# For IMOEX ticker parsing. Currently parsed: 7.268370607028754 %
# For IMOEX ticker parsing. Currently parsed: 7.348242811501597 %
# For IMOEX ticker parsing. Currently parsed: 7.4281150159744405 %
# For IMOEX ticker parsing. Currently parsed: 7.507987220447284 %
# For IMOEX ticker parsing. Currently parsed: 7.587859424920127 %
# For IMOEX ticker parsing. Currently parsed: 7.667731629392971 %
# For IMOEX ticker parsing. Currently parsed: 7.747603833865814 %
# For IMOEX ticker parsing. Currently parsed: 7.827476038338658 %
# For IMOEX ticker parsing. Currently parsed: 7.907348242811501 %
# For IMOEX ticker parsing. Currently parsed: 7.987220447284344 %
# For IMOEX ticker parsing. Currently parsed: 8.067092651757187 %
# For IMOEX ticker parsing. Currently parsed: 8.146964856230031 %
# For IMOEX ticker parsing. Currently parsed: 8.226837060702875 %
# For IMOEX ticker parsing. Currently parsed: 8.30670926517572 %
# For IMOEX ticker parsing. Currently parsed: 8.386581469648563 %
# For IMOEX ticker parsing. Currently parsed: 8.466453674121405 %
# For IMOEX ticker parsing. Currently parsed: 8.54632587859425 %
# For IMOEX ticker parsing. Currently parsed: 8.626198083067091 %
# For IMOEX ticker parsing. Currently parsed: 8.706070287539937 %
# For IMOEX ticker parsing. Currently parsed: 8.78594249201278 %
# For IMOEX ticker parsing. Currently parsed: 8.865814696485623 %
# For IMOEX ticker parsing. Currently parsed: 8.945686900958465 %
# For IMOEX ticker parsing. Currently parsed: 9.025559105431311 %
# For IMOEX ticker parsing. Currently parsed: 9.105431309904153 %
# For IMOEX ticker parsing. Currently parsed: 9.185303514376997 %
# For IMOEX ticker parsing. Currently parsed: 9.26517571884984 %
# For IMOEX ticker parsing. Currently parsed: 9.345047923322685 %
# For IMOEX ticker parsing. Currently parsed: 9.424920127795527 %
# For IMOEX ticker parsing. Currently parsed: 9.504792332268371 %
# For IMOEX ticker parsing. Currently parsed: 9.584664536741213 %
# For IMOEX ticker parsing. Currently parsed: 9.664536741214057 %
# For IMOEX ticker parsing. Currently parsed: 9.744408945686901 %
# For IMOEX ticker parsing. Currently parsed: 9.824281150159745 %
# For IMOEX ticker parsing. Currently parsed: 9.904153354632587 %
# For IMOEX ticker parsing. Currently parsed: 9.984025559105431 %
# For IMOEX ticker parsing. Currently parsed: 10.063897763578275 %
# For IMOEX ticker parsing. Currently parsed: 10.143769968051117 %
# For IMOEX ticker parsing. Currently parsed: 10.223642172523961 %
# For IMOEX ticker parsing. Currently parsed: 10.303514376996805 %
# For IMOEX ticker parsing. Currently parsed: 10.383386581469649 %
# For IMOEX ticker parsing. Currently parsed: 10.463258785942491 %
# For IMOEX ticker parsing. Currently parsed: 10.543130990415335 %
# For IMOEX ticker parsing. Currently parsed: 10.62300319488818 %
# For IMOEX ticker parsing. Currently parsed: 10.702875399361023 %
# For IMOEX ticker parsing. Currently parsed: 10.782747603833865 %
# For IMOEX ticker parsing. Currently parsed: 10.86261980830671 %
# For IMOEX ticker parsing. Currently parsed: 10.942492012779553 %
# For IMOEX ticker parsing. Currently parsed: 11.022364217252397 %
# For IMOEX ticker parsing. Currently parsed: 11.10223642172524 %
# For IMOEX ticker parsing. Currently parsed: 11.182108626198083 %
# For IMOEX ticker parsing. Currently parsed: 11.261980830670927 %
# For IMOEX ticker parsing. Currently parsed: 11.341853035143771 %
# For IMOEX ticker parsing. Currently parsed: 11.421725239616613 %
# For IMOEX ticker parsing. Currently parsed: 11.501597444089457 %
# For IMOEX ticker parsing. Currently parsed: 11.581469648562301 %
# For IMOEX ticker parsing. Currently parsed: 11.661341853035143 %
# For IMOEX ticker parsing. Currently parsed: 11.741214057507987 %
# For IMOEX ticker parsing. Currently parsed: 11.821086261980831 %
# For IMOEX ticker parsing. Currently parsed: 11.900958466453675 %
# For IMOEX ticker parsing. Currently parsed: 11.980830670926517 %
# For IMOEX ticker parsing. Currently parsed: 12.060702875399361 %
# For IMOEX ticker parsing. Currently parsed: 12.140575079872203 %
# For IMOEX ticker parsing. Currently parsed: 12.220447284345049 %
# For IMOEX ticker parsing. Currently parsed: 12.300319488817891 %
# For IMOEX ticker parsing. Currently parsed: 12.380191693290735 %
# For IMOEX ticker parsing. Currently parsed: 12.460063897763577 %
# For IMOEX ticker parsing. Currently parsed: 12.539936102236421 %
# For IMOEX ticker parsing. Currently parsed: 12.619808306709265 %
# For IMOEX ticker parsing. Currently parsed: 12.699680511182109 %
# For IMOEX ticker parsing. Currently parsed: 12.779552715654951 %
# For IMOEX ticker parsing. Currently parsed: 12.859424920127797 %
# For IMOEX ticker parsing. Currently parsed: 12.939297124600637 %
# For IMOEX ticker parsing. Currently parsed: 13.019169329073483 %
# For IMOEX ticker parsing. Currently parsed: 13.099041533546327 %
# For IMOEX ticker parsing. Currently parsed: 13.178913738019169 %
# For IMOEX ticker parsing. Currently parsed: 13.258785942492013 %
# For IMOEX ticker parsing. Currently parsed: 13.338658146964857 %
# For IMOEX ticker parsing. Currently parsed: 13.418530351437699 %
# For IMOEX ticker parsing. Currently parsed: 13.498402555910543 %
# For IMOEX ticker parsing. Currently parsed: 13.578274760383385 %
# For IMOEX ticker parsing. Currently parsed: 13.658146964856229 %
# For IMOEX ticker parsing. Currently parsed: 13.738019169329075 %
# For IMOEX ticker parsing. Currently parsed: 13.817891373801917 %
# For IMOEX ticker parsing. Currently parsed: 13.89776357827476 %
# For IMOEX ticker parsing. Currently parsed: 13.977635782747605 %
# For IMOEX ticker parsing. Currently parsed: 14.057507987220447 %
# For IMOEX ticker parsing. Currently parsed: 14.13738019169329 %
# For IMOEX ticker parsing. Currently parsed: 14.217252396166133 %
# For IMOEX ticker parsing. Currently parsed: 14.297124600638977 %
# For IMOEX ticker parsing. Currently parsed: 14.376996805111823 %
# For IMOEX ticker parsing. Currently parsed: 14.456869009584663 %
# For IMOEX ticker parsing. Currently parsed: 14.536741214057509 %
# For IMOEX ticker parsing. Currently parsed: 14.616613418530353 %
# For IMOEX ticker parsing. Currently parsed: 14.696485623003195 %
# For IMOEX ticker parsing. Currently parsed: 14.776357827476039 %
# For IMOEX ticker parsing. Currently parsed: 14.856230031948881 %
# For IMOEX ticker parsing. Currently parsed: 14.936102236421725 %
# For IMOEX ticker parsing. Currently parsed: 15.015974440894569 %
# For IMOEX ticker parsing. Currently parsed: 15.095846645367411 %
# For IMOEX ticker parsing. Currently parsed: 15.175718849840255 %
# For IMOEX ticker parsing. Currently parsed: 15.2555910543131 %
# For IMOEX ticker parsing. Currently parsed: 15.335463258785943 %
# For IMOEX ticker parsing. Currently parsed: 15.415335463258787 %
# For IMOEX ticker parsing. Currently parsed: 15.495207667731629 %
# For IMOEX ticker parsing. Currently parsed: 15.575079872204473 %
# For IMOEX ticker parsing. Currently parsed: 15.654952076677317 %
# For IMOEX ticker parsing. Currently parsed: 15.734824281150159 %
# For IMOEX ticker parsing. Currently parsed: 15.814696485623003 %
# For IMOEX ticker parsing. Currently parsed: 15.894568690095848 %
# For IMOEX ticker parsing. Currently parsed: 15.974440894568689 %
# For IMOEX ticker parsing. Currently parsed: 16.054313099041533 %
# For IMOEX ticker parsing. Currently parsed: 16.134185303514375 %
# For IMOEX ticker parsing. Currently parsed: 16.21405750798722 %
# For IMOEX ticker parsing. Currently parsed: 16.293929712460063 %
# For IMOEX ticker parsing. Currently parsed: 16.373801916932905 %
# For IMOEX ticker parsing. Currently parsed: 16.45367412140575 %
# For IMOEX ticker parsing. Currently parsed: 16.533546325878596 %
# For IMOEX ticker parsing. Currently parsed: 16.61341853035144 %
# For IMOEX ticker parsing. Currently parsed: 16.69329073482428 %
# For IMOEX ticker parsing. Currently parsed: 16.773162939297126 %
# For IMOEX ticker parsing. Currently parsed: 16.85303514376997 %
# For IMOEX ticker parsing. Currently parsed: 16.93290734824281 %
# For IMOEX ticker parsing. Currently parsed: 17.012779552715653 %
# For IMOEX ticker parsing. Currently parsed: 17.0926517571885 %
# For IMOEX ticker parsing. Currently parsed: 17.172523961661344 %
# For IMOEX ticker parsing. Currently parsed: 17.252396166134183 %
# For IMOEX ticker parsing. Currently parsed: 17.33226837060703 %
# For IMOEX ticker parsing. Currently parsed: 17.412140575079874 %
# For IMOEX ticker parsing. Currently parsed: 17.492012779552716 %
# For IMOEX ticker parsing. Currently parsed: 17.57188498402556 %
# For IMOEX ticker parsing. Currently parsed: 17.6517571884984 %
# For IMOEX ticker parsing. Currently parsed: 17.731629392971247 %
# For IMOEX ticker parsing. Currently parsed: 17.811501597444092 %
# For IMOEX ticker parsing. Currently parsed: 17.89137380191693 %
# For IMOEX ticker parsing. Currently parsed: 17.971246006389777 %
# For IMOEX ticker parsing. Currently parsed: 18.051118210862622 %
# For IMOEX ticker parsing. Currently parsed: 18.130990415335464 %
# For IMOEX ticker parsing. Currently parsed: 18.210862619808307 %
# For IMOEX ticker parsing. Currently parsed: 18.29073482428115 %
# For IMOEX ticker parsing. Currently parsed: 18.370607028753994 %
# For IMOEX ticker parsing. Currently parsed: 18.450479233226837 %
# For IMOEX ticker parsing. Currently parsed: 18.53035143769968 %
# For IMOEX ticker parsing. Currently parsed: 18.610223642172524 %
# For IMOEX ticker parsing. Currently parsed: 18.69009584664537 %
# For IMOEX ticker parsing. Currently parsed: 18.76996805111821 %
# For IMOEX ticker parsing. Currently parsed: 18.849840255591054 %
# For IMOEX ticker parsing. Currently parsed: 18.929712460063897 %
# For IMOEX ticker parsing. Currently parsed: 19.009584664536742 %
# For IMOEX ticker parsing. Currently parsed: 19.089456869009584 %
# For IMOEX ticker parsing. Currently parsed: 19.169329073482427 %
# For IMOEX ticker parsing. Currently parsed: 19.249201277955272 %
# For IMOEX ticker parsing. Currently parsed: 19.329073482428115 %
# For IMOEX ticker parsing. Currently parsed: 19.408945686900957 %
# For IMOEX ticker parsing. Currently parsed: 19.488817891373802 %
# For IMOEX ticker parsing. Currently parsed: 19.568690095846645 %
# For IMOEX ticker parsing. Currently parsed: 19.64856230031949 %
# For IMOEX ticker parsing. Currently parsed: 19.728434504792332 %
# For IMOEX ticker parsing. Currently parsed: 19.808306709265175 %
# For IMOEX ticker parsing. Currently parsed: 19.88817891373802 %
# For IMOEX ticker parsing. Currently parsed: 19.968051118210862 %
# For IMOEX ticker parsing. Currently parsed: 20.047923322683705 %
# For IMOEX ticker parsing. Currently parsed: 20.12779552715655 %
# For IMOEX ticker parsing. Currently parsed: 20.207667731629392 %
# For IMOEX ticker parsing. Currently parsed: 20.287539936102235 %
# For IMOEX ticker parsing. Currently parsed: 20.36741214057508 %
# For IMOEX ticker parsing. Currently parsed: 20.447284345047922 %
# For IMOEX ticker parsing. Currently parsed: 20.527156549520768 %
# For IMOEX ticker parsing. Currently parsed: 20.60702875399361 %
# For IMOEX ticker parsing. Currently parsed: 20.686900958466452 %
# For IMOEX ticker parsing. Currently parsed: 20.766773162939298 %
# For IMOEX ticker parsing. Currently parsed: 20.84664536741214 %
# For IMOEX ticker parsing. Currently parsed: 20.926517571884983 %
# For IMOEX ticker parsing. Currently parsed: 21.00638977635783 %
# For IMOEX ticker parsing. Currently parsed: 21.08626198083067 %
# For IMOEX ticker parsing. Currently parsed: 21.166134185303516 %
# For IMOEX ticker parsing. Currently parsed: 21.24600638977636 %
# For IMOEX ticker parsing. Currently parsed: 21.3258785942492 %
# For IMOEX ticker parsing. Currently parsed: 21.405750798722046 %
# For IMOEX ticker parsing. Currently parsed: 21.48562300319489 %
# For IMOEX ticker parsing. Currently parsed: 21.56549520766773 %
# For IMOEX ticker parsing. Currently parsed: 21.645367412140576 %
# For IMOEX ticker parsing. Currently parsed: 21.72523961661342 %
# For IMOEX ticker parsing. Currently parsed: 21.80511182108626 %
# For IMOEX ticker parsing. Currently parsed: 21.884984025559106 %
# For IMOEX ticker parsing. Currently parsed: 21.96485623003195 %
# For IMOEX ticker parsing. Currently parsed: 22.044728434504794 %
# For IMOEX ticker parsing. Currently parsed: 22.124600638977636 %
# For IMOEX ticker parsing. Currently parsed: 22.20447284345048 %
# For IMOEX ticker parsing. Currently parsed: 22.284345047923324 %
# For IMOEX ticker parsing. Currently parsed: 22.364217252396166 %
# For IMOEX ticker parsing. Currently parsed: 22.44408945686901 %
# For IMOEX ticker parsing. Currently parsed: 22.523961661341854 %
# For IMOEX ticker parsing. Currently parsed: 22.603833865814696 %
# For IMOEX ticker parsing. Currently parsed: 22.683706070287542 %
# For IMOEX ticker parsing. Currently parsed: 22.76357827476038 %
# For IMOEX ticker parsing. Currently parsed: 22.843450479233226 %
# For IMOEX ticker parsing. Currently parsed: 22.923322683706072 %
# For IMOEX ticker parsing. Currently parsed: 23.003194888178914 %
# For IMOEX ticker parsing. Currently parsed: 23.083067092651756 %
# For IMOEX ticker parsing. Currently parsed: 23.162939297124602 %
# For IMOEX ticker parsing. Currently parsed: 23.242811501597444 %
# For IMOEX ticker parsing. Currently parsed: 23.322683706070286 %
# For IMOEX ticker parsing. Currently parsed: 23.40255591054313 %
# For IMOEX ticker parsing. Currently parsed: 23.482428115015974 %
# For IMOEX ticker parsing. Currently parsed: 23.56230031948882 %
# For IMOEX ticker parsing. Currently parsed: 23.642172523961662 %
# For IMOEX ticker parsing. Currently parsed: 23.722044728434504 %
# For IMOEX ticker parsing. Currently parsed: 23.80191693290735 %
# For IMOEX ticker parsing. Currently parsed: 23.881789137380192 %
# For IMOEX ticker parsing. Currently parsed: 23.961661341853034 %
# For IMOEX ticker parsing. Currently parsed: 24.041533546325876 %
# For IMOEX ticker parsing. Currently parsed: 24.121405750798722 %
# For IMOEX ticker parsing. Currently parsed: 24.201277955271568 %
# For IMOEX ticker parsing. Currently parsed: 24.281150159744406 %
# For IMOEX ticker parsing. Currently parsed: 24.361022364217252 %
# For IMOEX ticker parsing. Currently parsed: 24.440894568690098 %
# For IMOEX ticker parsing. Currently parsed: 24.52076677316294 %
# For IMOEX ticker parsing. Currently parsed: 24.600638977635782 %
# For IMOEX ticker parsing. Currently parsed: 24.680511182108624 %
# For IMOEX ticker parsing. Currently parsed: 24.76038338658147 %
# For IMOEX ticker parsing. Currently parsed: 24.840255591054312 %
# For IMOEX ticker parsing. Currently parsed: 24.920127795527154 %
# For IMOEX ticker parsing. Currently parsed: 25.0 %
# For IMOEX ticker parsing. Currently parsed: 25.079872204472842 %
# For IMOEX ticker parsing. Currently parsed: 25.159744408945688 %
# For IMOEX ticker parsing. Currently parsed: 25.23961661341853 %
# For IMOEX ticker parsing. Currently parsed: 25.319488817891372 %
# For IMOEX ticker parsing. Currently parsed: 25.399361022364218 %
# For IMOEX ticker parsing. Currently parsed: 25.47923322683706 %
# For IMOEX ticker parsing. Currently parsed: 25.559105431309902 %
# For IMOEX ticker parsing. Currently parsed: 25.63897763578275 %
# For IMOEX ticker parsing. Currently parsed: 25.718849840255594 %
# For IMOEX ticker parsing. Currently parsed: 25.798722044728432 %
# For IMOEX ticker parsing. Currently parsed: 25.878594249201274 %
# For IMOEX ticker parsing. Currently parsed: 25.958466453674124 %
# For IMOEX ticker parsing. Currently parsed: 26.038338658146966 %
# For IMOEX ticker parsing. Currently parsed: 26.118210862619804 %
# For IMOEX ticker parsing. Currently parsed: 26.198083067092654 %
# For IMOEX ticker parsing. Currently parsed: 26.277955271565496 %
# For IMOEX ticker parsing. Currently parsed: 26.357827476038338 %
# For IMOEX ticker parsing. Currently parsed: 26.437699680511184 %
# For IMOEX ticker parsing. Currently parsed: 26.517571884984026 %
# For IMOEX ticker parsing. Currently parsed: 26.597444089456868 %
# For IMOEX ticker parsing. Currently parsed: 26.677316293929714 %
# For IMOEX ticker parsing. Currently parsed: 26.757188498402556 %
# For IMOEX ticker parsing. Currently parsed: 26.837060702875398 %
# For IMOEX ticker parsing. Currently parsed: 26.916932907348247 %
# For IMOEX ticker parsing. Currently parsed: 26.996805111821086 %
# For IMOEX ticker parsing. Currently parsed: 27.076677316293928 %
# For IMOEX ticker parsing. Currently parsed: 27.15654952076677 %
# For IMOEX ticker parsing. Currently parsed: 27.23642172523962 %
# For IMOEX ticker parsing. Currently parsed: 27.316293929712458 %
# For IMOEX ticker parsing. Currently parsed: 27.3961661341853 %
# For IMOEX ticker parsing. Currently parsed: 27.47603833865815 %
# For IMOEX ticker parsing. Currently parsed: 27.55591054313099 %
# For IMOEX ticker parsing. Currently parsed: 27.635782747603834 %
# For IMOEX ticker parsing. Currently parsed: 27.71565495207668 %
# For IMOEX ticker parsing. Currently parsed: 27.79552715654952 %
# For IMOEX ticker parsing. Currently parsed: 27.875399361022364 %
# For IMOEX ticker parsing. Currently parsed: 27.95527156549521 %
# For IMOEX ticker parsing. Currently parsed: 28.03514376996805 %
# For IMOEX ticker parsing. Currently parsed: 28.115015974440894 %
# For IMOEX ticker parsing. Currently parsed: 28.19488817891374 %
# For IMOEX ticker parsing. Currently parsed: 28.27476038338658 %
# For IMOEX ticker parsing. Currently parsed: 28.354632587859424 %
# For IMOEX ticker parsing. Currently parsed: 28.434504792332266 %
# For IMOEX ticker parsing. Currently parsed: 28.51437699680511 %
# For IMOEX ticker parsing. Currently parsed: 28.594249201277954 %
# For IMOEX ticker parsing. Currently parsed: 28.674121405750796 %
# For IMOEX ticker parsing. Currently parsed: 28.753993610223645 %
# For IMOEX ticker parsing. Currently parsed: 28.833865814696484 %
# For IMOEX ticker parsing. Currently parsed: 28.913738019169326 %
# For IMOEX ticker parsing. Currently parsed: 28.993610223642175 %
# For IMOEX ticker parsing. Currently parsed: 29.073482428115017 %
# For IMOEX ticker parsing. Currently parsed: 29.153354632587856 %
# For IMOEX ticker parsing. Currently parsed: 29.233226837060705 %
# For IMOEX ticker parsing. Currently parsed: 29.313099041533548 %
# For IMOEX ticker parsing. Currently parsed: 29.39297124600639 %
# For IMOEX ticker parsing. Currently parsed: 29.472843450479235 %
# For IMOEX ticker parsing. Currently parsed: 29.552715654952078 %
# For IMOEX ticker parsing. Currently parsed: 29.63258785942492 %
# For IMOEX ticker parsing. Currently parsed: 29.712460063897762 %
# For IMOEX ticker parsing. Currently parsed: 29.792332268370608 %
# For IMOEX ticker parsing. Currently parsed: 29.87220447284345 %
# For IMOEX ticker parsing. Currently parsed: 29.952076677316292 %
# For IMOEX ticker parsing. Currently parsed: 30.031948881789138 %
# For IMOEX ticker parsing. Currently parsed: 30.11182108626198 %
# For IMOEX ticker parsing. Currently parsed: 30.191693290734822 %
# For IMOEX ticker parsing. Currently parsed: 30.27156549520767 %
# For IMOEX ticker parsing. Currently parsed: 30.35143769968051 %
# For IMOEX ticker parsing. Currently parsed: 30.431309904153352 %
# For IMOEX ticker parsing. Currently parsed: 30.5111821086262 %
# For IMOEX ticker parsing. Currently parsed: 30.591054313099043 %
# For IMOEX ticker parsing. Currently parsed: 30.670926517571885 %
# For IMOEX ticker parsing. Currently parsed: 30.75079872204473 %
# For IMOEX ticker parsing. Currently parsed: 30.830670926517573 %
# For IMOEX ticker parsing. Currently parsed: 30.910543130990416 %
# For IMOEX ticker parsing. Currently parsed: 30.990415335463258 %
# For IMOEX ticker parsing. Currently parsed: 31.070287539936103 %
# For IMOEX ticker parsing. Currently parsed: 31.150159744408946 %
# For IMOEX ticker parsing. Currently parsed: 31.230031948881788 %
# For IMOEX ticker parsing. Currently parsed: 31.309904153354633 %
# For IMOEX ticker parsing. Currently parsed: 31.389776357827476 %
# For IMOEX ticker parsing. Currently parsed: 31.469648562300318 %
# For IMOEX ticker parsing. Currently parsed: 31.549520766773163 %
# For IMOEX ticker parsing. Currently parsed: 31.629392971246006 %
# For IMOEX ticker parsing. Currently parsed: 31.709265175718848 %
# For IMOEX ticker parsing. Currently parsed: 31.789137380191697 %
# For IMOEX ticker parsing. Currently parsed: 31.869009584664536 %
# For IMOEX ticker parsing. Currently parsed: 31.948881789137378 %
# For IMOEX ticker parsing. Currently parsed: 32.02875399361022 %
# For IMOEX ticker parsing. Currently parsed: 32.108626198083066 %
# For IMOEX ticker parsing. Currently parsed: 32.18849840255591 %
# For IMOEX ticker parsing. Currently parsed: 32.26837060702875 %
# For IMOEX ticker parsing. Currently parsed: 32.3482428115016 %
# For IMOEX ticker parsing. Currently parsed: 32.42811501597444 %
# For IMOEX ticker parsing. Currently parsed: 32.50798722044728 %
# For IMOEX ticker parsing. Currently parsed: 32.587859424920126 %
# For IMOEX ticker parsing. Currently parsed: 32.66773162939297 %
# For IMOEX ticker parsing. Currently parsed: 32.74760383386581 %
# For IMOEX ticker parsing. Currently parsed: 32.82747603833866 %
# For IMOEX ticker parsing. Currently parsed: 32.9073482428115 %
# For IMOEX ticker parsing. Currently parsed: 32.98722044728434 %
# For IMOEX ticker parsing. Currently parsed: 33.06709265175719 %
# For IMOEX ticker parsing. Currently parsed: 33.146964856230035 %
# For IMOEX ticker parsing. Currently parsed: 33.22683706070288 %
# For IMOEX ticker parsing. Currently parsed: 33.30670926517572 %
# For IMOEX ticker parsing. Currently parsed: 33.38658146964856 %
# For IMOEX ticker parsing. Currently parsed: 33.466453674121404 %
# For IMOEX ticker parsing. Currently parsed: 33.54632587859425 %
# For IMOEX ticker parsing. Currently parsed: 33.626198083067095 %
# For IMOEX ticker parsing. Currently parsed: 33.70607028753994 %
# For IMOEX ticker parsing. Currently parsed: 33.78594249201278 %
# For IMOEX ticker parsing. Currently parsed: 33.86581469648562 %
# For IMOEX ticker parsing. Currently parsed: 33.945686900958464 %
# For IMOEX ticker parsing. Currently parsed: 34.025559105431306 %
# For IMOEX ticker parsing. Currently parsed: 34.105431309904155 %
# For IMOEX ticker parsing. Currently parsed: 34.185303514377 %
# For IMOEX ticker parsing. Currently parsed: 34.26517571884984 %
# For IMOEX ticker parsing. Currently parsed: 34.34504792332269 %
# For IMOEX ticker parsing. Currently parsed: 34.42492012779553 %
# For IMOEX ticker parsing. Currently parsed: 34.504792332268366 %
# For IMOEX ticker parsing. Currently parsed: 34.584664536741215 %
# For IMOEX ticker parsing. Currently parsed: 34.66453674121406 %
# For IMOEX ticker parsing. Currently parsed: 34.7444089456869 %
# For IMOEX ticker parsing. Currently parsed: 34.82428115015975 %
# For IMOEX ticker parsing. Currently parsed: 34.90415335463259 %
# For IMOEX ticker parsing. Currently parsed: 34.98402555910543 %
# For IMOEX ticker parsing. Currently parsed: 35.063897763578275 %
# For IMOEX ticker parsing. Currently parsed: 35.14376996805112 %
# For IMOEX ticker parsing. Currently parsed: 35.22364217252396 %
# For IMOEX ticker parsing. Currently parsed: 35.3035143769968 %
# For IMOEX ticker parsing. Currently parsed: 35.38338658146965 %
# For IMOEX ticker parsing. Currently parsed: 35.46325878594249 %
# For IMOEX ticker parsing. Currently parsed: 35.543130990415335 %
# For IMOEX ticker parsing. Currently parsed: 35.623003194888184 %
# For IMOEX ticker parsing. Currently parsed: 35.70287539936102 %
# For IMOEX ticker parsing. Currently parsed: 35.78274760383386 %
# For IMOEX ticker parsing. Currently parsed: 35.86261980830671 %
# For IMOEX ticker parsing. Currently parsed: 35.94249201277955 %
# For IMOEX ticker parsing. Currently parsed: 36.022364217252395 %
# For IMOEX ticker parsing. Currently parsed: 36.102236421725244 %
# For IMOEX ticker parsing. Currently parsed: 36.18210862619809 %
# For IMOEX ticker parsing. Currently parsed: 36.26198083067093 %
# For IMOEX ticker parsing. Currently parsed: 36.34185303514377 %
# For IMOEX ticker parsing. Currently parsed: 36.42172523961661 %
# For IMOEX ticker parsing. Currently parsed: 36.501597444089455 %
# For IMOEX ticker parsing. Currently parsed: 36.5814696485623 %
# For IMOEX ticker parsing. Currently parsed: 36.66134185303515 %
# For IMOEX ticker parsing. Currently parsed: 36.74121405750799 %
# For IMOEX ticker parsing. Currently parsed: 36.82108626198083 %
# For IMOEX ticker parsing. Currently parsed: 36.90095846645367 %
# For IMOEX ticker parsing. Currently parsed: 36.980830670926515 %
# For IMOEX ticker parsing. Currently parsed: 37.06070287539936 %
# For IMOEX ticker parsing. Currently parsed: 37.14057507987221 %
# For IMOEX ticker parsing. Currently parsed: 37.22044728434505 %
# For IMOEX ticker parsing. Currently parsed: 37.30031948881789 %
# For IMOEX ticker parsing. Currently parsed: 37.38019169329074 %
# For IMOEX ticker parsing. Currently parsed: 37.46006389776358 %
# For IMOEX ticker parsing. Currently parsed: 37.53993610223642 %
# For IMOEX ticker parsing. Currently parsed: 37.61980830670926 %
# For IMOEX ticker parsing. Currently parsed: 37.69968051118211 %
# For IMOEX ticker parsing. Currently parsed: 37.77955271565495 %
# For IMOEX ticker parsing. Currently parsed: 37.85942492012779 %
# For IMOEX ticker parsing. Currently parsed: 37.93929712460064 %
# For IMOEX ticker parsing. Currently parsed: 38.019169329073485 %
# For IMOEX ticker parsing. Currently parsed: 38.09904153354633 %
# For IMOEX ticker parsing. Currently parsed: 38.17891373801917 %
# For IMOEX ticker parsing. Currently parsed: 38.25878594249201 %
# For IMOEX ticker parsing. Currently parsed: 38.33865814696485 %
# For IMOEX ticker parsing. Currently parsed: 38.4185303514377 %
# For IMOEX ticker parsing. Currently parsed: 38.498402555910545 %
# For IMOEX ticker parsing. Currently parsed: 38.57827476038339 %
# For IMOEX ticker parsing. Currently parsed: 38.65814696485623 %
# For IMOEX ticker parsing. Currently parsed: 38.73801916932907 %
# For IMOEX ticker parsing. Currently parsed: 38.81789137380191 %
# For IMOEX ticker parsing. Currently parsed: 38.897763578274756 %
# For IMOEX ticker parsing. Currently parsed: 38.977635782747605 %
# For IMOEX ticker parsing. Currently parsed: 39.05750798722045 %
# For IMOEX ticker parsing. Currently parsed: 39.13738019169329 %
# For IMOEX ticker parsing. Currently parsed: 39.21725239616614 %
# For IMOEX ticker parsing. Currently parsed: 39.29712460063898 %
# For IMOEX ticker parsing. Currently parsed: 39.376996805111816 %
# For IMOEX ticker parsing. Currently parsed: 39.456869009584665 %
# For IMOEX ticker parsing. Currently parsed: 39.53674121405751 %
# For IMOEX ticker parsing. Currently parsed: 39.61661341853035 %
# For IMOEX ticker parsing. Currently parsed: 39.6964856230032 %
# For IMOEX ticker parsing. Currently parsed: 39.77635782747604 %
# For IMOEX ticker parsing. Currently parsed: 39.85623003194888 %
# For IMOEX ticker parsing. Currently parsed: 39.936102236421725 %
# For IMOEX ticker parsing. Currently parsed: 40.01597444089457 %
# For IMOEX ticker parsing. Currently parsed: 40.09584664536741 %
# For IMOEX ticker parsing. Currently parsed: 40.17571884984025 %
# For IMOEX ticker parsing. Currently parsed: 40.2555910543131 %
# For IMOEX ticker parsing. Currently parsed: 40.33546325878594 %
# For IMOEX ticker parsing. Currently parsed: 40.415335463258785 %
# For IMOEX ticker parsing. Currently parsed: 40.495207667731634 %
# For IMOEX ticker parsing. Currently parsed: 40.57507987220447 %
# For IMOEX ticker parsing. Currently parsed: 40.65495207667731 %
# For IMOEX ticker parsing. Currently parsed: 40.73482428115016 %
# For IMOEX ticker parsing. Currently parsed: 40.814696485623 %
# For IMOEX ticker parsing. Currently parsed: 40.894568690095845 %
# For IMOEX ticker parsing. Currently parsed: 40.974440894568694 %
# For IMOEX ticker parsing. Currently parsed: 41.054313099041536 %
# For IMOEX ticker parsing. Currently parsed: 41.13418530351438 %
# For IMOEX ticker parsing. Currently parsed: 41.21405750798722 %
# For IMOEX ticker parsing. Currently parsed: 41.29392971246006 %
# For IMOEX ticker parsing. Currently parsed: 41.373801916932905 %
# For IMOEX ticker parsing. Currently parsed: 41.45367412140575 %
# For IMOEX ticker parsing. Currently parsed: 41.533546325878596 %
# For IMOEX ticker parsing. Currently parsed: 41.61341853035144 %
# For IMOEX ticker parsing. Currently parsed: 41.69329073482428 %
# For IMOEX ticker parsing. Currently parsed: 41.77316293929712 %
# For IMOEX ticker parsing. Currently parsed: 41.853035143769965 %
# For IMOEX ticker parsing. Currently parsed: 41.93290734824281 %
# For IMOEX ticker parsing. Currently parsed: 42.01277955271566 %
# For IMOEX ticker parsing. Currently parsed: 42.0926517571885 %
# For IMOEX ticker parsing. Currently parsed: 42.17252396166134 %
# For IMOEX ticker parsing. Currently parsed: 42.25239616613419 %
# For IMOEX ticker parsing. Currently parsed: 42.33226837060703 %
# For IMOEX ticker parsing. Currently parsed: 42.412140575079874 %
# For IMOEX ticker parsing. Currently parsed: 42.49201277955272 %
# For IMOEX ticker parsing. Currently parsed: 42.57188498402556 %
# For IMOEX ticker parsing. Currently parsed: 42.6517571884984 %
# For IMOEX ticker parsing. Currently parsed: 42.73162939297125 %
# For IMOEX ticker parsing. Currently parsed: 42.81150159744409 %
# For IMOEX ticker parsing. Currently parsed: 42.891373801916934 %
# For IMOEX ticker parsing. Currently parsed: 42.97124600638978 %
# For IMOEX ticker parsing. Currently parsed: 43.05111821086262 %
# For IMOEX ticker parsing. Currently parsed: 43.13099041533546 %
# For IMOEX ticker parsing. Currently parsed: 43.2108626198083 %
# For IMOEX ticker parsing. Currently parsed: 43.29073482428115 %
# For IMOEX ticker parsing. Currently parsed: 43.370607028753994 %
# For IMOEX ticker parsing. Currently parsed: 43.45047923322684 %
# For IMOEX ticker parsing. Currently parsed: 43.530351437699686 %
# For IMOEX ticker parsing. Currently parsed: 43.61022364217252 %
# For IMOEX ticker parsing. Currently parsed: 43.69009584664536 %
# For IMOEX ticker parsing. Currently parsed: 43.76996805111821 %
# For IMOEX ticker parsing. Currently parsed: 43.849840255591054 %
# For IMOEX ticker parsing. Currently parsed: 43.9297124600639 %
# For IMOEX ticker parsing. Currently parsed: 44.009584664536746 %
# For IMOEX ticker parsing. Currently parsed: 44.08945686900959 %
# For IMOEX ticker parsing. Currently parsed: 44.16932907348243 %
# For IMOEX ticker parsing. Currently parsed: 44.24920127795527 %
# For IMOEX ticker parsing. Currently parsed: 44.329073482428115 %
# For IMOEX ticker parsing. Currently parsed: 44.40894568690096 %
# For IMOEX ticker parsing. Currently parsed: 44.4888178913738 %
# For IMOEX ticker parsing. Currently parsed: 44.56869009584665 %
# For IMOEX ticker parsing. Currently parsed: 44.64856230031949 %
# For IMOEX ticker parsing. Currently parsed: 44.72843450479233 %
# For IMOEX ticker parsing. Currently parsed: 44.808306709265175 %
# For IMOEX ticker parsing. Currently parsed: 44.88817891373802 %
# For IMOEX ticker parsing. Currently parsed: 44.96805111821086 %
# For IMOEX ticker parsing. Currently parsed: 45.04792332268371 %
# For IMOEX ticker parsing. Currently parsed: 45.12779552715655 %
# For IMOEX ticker parsing. Currently parsed: 45.20766773162939 %
# For IMOEX ticker parsing. Currently parsed: 45.28753993610224 %
# For IMOEX ticker parsing. Currently parsed: 45.367412140575084 %
# For IMOEX ticker parsing. Currently parsed: 45.44728434504792 %
# For IMOEX ticker parsing. Currently parsed: 45.52715654952076 %
# For IMOEX ticker parsing. Currently parsed: 45.60702875399361 %
# For IMOEX ticker parsing. Currently parsed: 45.68690095846645 %
# For IMOEX ticker parsing. Currently parsed: 45.766773162939295 %
# For IMOEX ticker parsing. Currently parsed: 45.846645367412144 %
# For IMOEX ticker parsing. Currently parsed: 45.926517571884986 %
# For IMOEX ticker parsing. Currently parsed: 46.00638977635783 %
# For IMOEX ticker parsing. Currently parsed: 46.08626198083067 %
# For IMOEX ticker parsing. Currently parsed: 46.16613418530351 %
# For IMOEX ticker parsing. Currently parsed: 46.246006389776355 %
# For IMOEX ticker parsing. Currently parsed: 46.325878594249204 %
# For IMOEX ticker parsing. Currently parsed: 46.405750798722046 %
# For IMOEX ticker parsing. Currently parsed: 46.48562300319489 %
# For IMOEX ticker parsing. Currently parsed: 46.56549520766774 %
# For IMOEX ticker parsing. Currently parsed: 46.64536741214057 %
# For IMOEX ticker parsing. Currently parsed: 46.725239616613415 %
# For IMOEX ticker parsing. Currently parsed: 46.80511182108626 %
# For IMOEX ticker parsing. Currently parsed: 46.884984025559106 %
# For IMOEX ticker parsing. Currently parsed: 46.96485623003195 %
# For IMOEX ticker parsing. Currently parsed: 47.04472843450479 %
# For IMOEX ticker parsing. Currently parsed: 47.12460063897764 %
# For IMOEX ticker parsing. Currently parsed: 47.20447284345048 %
# For IMOEX ticker parsing. Currently parsed: 47.284345047923324 %
# For IMOEX ticker parsing. Currently parsed: 47.364217252396166 %
# For IMOEX ticker parsing. Currently parsed: 47.44408945686901 %
# For IMOEX ticker parsing. Currently parsed: 47.52396166134185 %
# For IMOEX ticker parsing. Currently parsed: 47.6038338658147 %
# For IMOEX ticker parsing. Currently parsed: 47.68370607028754 %
# For IMOEX ticker parsing. Currently parsed: 47.763578274760384 %
# For IMOEX ticker parsing. Currently parsed: 47.843450479233226 %
# For IMOEX ticker parsing. Currently parsed: 47.92332268370607 %
# For IMOEX ticker parsing. Currently parsed: 48.00319488817891 %
# For IMOEX ticker parsing. Currently parsed: 48.08306709265175 %
# For IMOEX ticker parsing. Currently parsed: 48.1629392971246 %
# For IMOEX ticker parsing. Currently parsed: 48.242811501597444 %
# For IMOEX ticker parsing. Currently parsed: 48.322683706070286 %
# For IMOEX ticker parsing. Currently parsed: 48.402555910543136 %
# For IMOEX ticker parsing. Currently parsed: 48.48242811501598 %
# For IMOEX ticker parsing. Currently parsed: 48.56230031948881 %
# For IMOEX ticker parsing. Currently parsed: 48.64217252396166 %
# For IMOEX ticker parsing. Currently parsed: 48.722044728434504 %
# For IMOEX ticker parsing. Currently parsed: 48.801916932907346 %
# For IMOEX ticker parsing. Currently parsed: 48.881789137380196 %
# For IMOEX ticker parsing. Currently parsed: 48.96166134185304 %
# For IMOEX ticker parsing. Currently parsed: 49.04153354632588 %
# For IMOEX ticker parsing. Currently parsed: 49.12140575079872 %
# For IMOEX ticker parsing. Currently parsed: 49.201277955271564 %
# For IMOEX ticker parsing. Currently parsed: 49.281150159744406 %
# For IMOEX ticker parsing. Currently parsed: 49.36102236421725 %
# For IMOEX ticker parsing. Currently parsed: 49.4408945686901 %
# For IMOEX ticker parsing. Currently parsed: 49.52076677316294 %
# For IMOEX ticker parsing. Currently parsed: 49.60063897763578 %
# For IMOEX ticker parsing. Currently parsed: 49.680511182108624 %
# For IMOEX ticker parsing. Currently parsed: 49.760383386581466 %
# For IMOEX ticker parsing. Currently parsed: 49.84025559105431 %
# For IMOEX ticker parsing. Currently parsed: 49.92012779552716 %
# For IMOEX ticker parsing. Currently parsed: 50.0 %
# For IMOEX ticker parsing. Currently parsed: 50.07987220447284 %
# For IMOEX ticker parsing. Currently parsed: 50.159744408945684 %
# For IMOEX ticker parsing. Currently parsed: 50.23961661341853 %
# For IMOEX ticker parsing. Currently parsed: 50.319488817891376 %
# For IMOEX ticker parsing. Currently parsed: 50.39936102236422 %
# For IMOEX ticker parsing. Currently parsed: 50.47923322683706 %
# For IMOEX ticker parsing. Currently parsed: 50.5591054313099 %
# For IMOEX ticker parsing. Currently parsed: 50.638977635782744 %
# For IMOEX ticker parsing. Currently parsed: 50.71884984025559 %
# For IMOEX ticker parsing. Currently parsed: 50.798722044728436 %
# For IMOEX ticker parsing. Currently parsed: 50.87859424920128 %
# For IMOEX ticker parsing. Currently parsed: 50.95846645367412 %
# For IMOEX ticker parsing. Currently parsed: 51.03833865814696 %
# For IMOEX ticker parsing. Currently parsed: 51.118210862619804 %
# For IMOEX ticker parsing. Currently parsed: 51.19808306709265 %
# For IMOEX ticker parsing. Currently parsed: 51.2779552715655 %
# For IMOEX ticker parsing. Currently parsed: 51.357827476038345 %
# For IMOEX ticker parsing. Currently parsed: 51.43769968051119 %
# For IMOEX ticker parsing. Currently parsed: 51.51757188498402 %
# For IMOEX ticker parsing. Currently parsed: 51.597444089456864 %
# For IMOEX ticker parsing. Currently parsed: 51.67731629392971 %
# For IMOEX ticker parsing. Currently parsed: 51.75718849840255 %
# For IMOEX ticker parsing. Currently parsed: 51.837060702875405 %
# For IMOEX ticker parsing. Currently parsed: 51.91693290734825 %
# For IMOEX ticker parsing. Currently parsed: 51.99680511182109 %
# For IMOEX ticker parsing. Currently parsed: 52.07667731629393 %
# For IMOEX ticker parsing. Currently parsed: 52.156549520766774 %
# For IMOEX ticker parsing. Currently parsed: 52.23642172523961 %
# For IMOEX ticker parsing. Currently parsed: 52.316293929712465 %
# For IMOEX ticker parsing. Currently parsed: 52.39616613418531 %
# For IMOEX ticker parsing. Currently parsed: 52.47603833865815 %
# For IMOEX ticker parsing. Currently parsed: 52.55591054313099 %
# For IMOEX ticker parsing. Currently parsed: 52.635782747603834 %
# For IMOEX ticker parsing. Currently parsed: 52.715654952076676 %
# For IMOEX ticker parsing. Currently parsed: 52.79552715654952 %
# For IMOEX ticker parsing. Currently parsed: 52.87539936102237 %
# For IMOEX ticker parsing. Currently parsed: 52.95527156549521 %
# For IMOEX ticker parsing. Currently parsed: 53.03514376996805 %
# For IMOEX ticker parsing. Currently parsed: 53.115015974440894 %
# For IMOEX ticker parsing. Currently parsed: 53.194888178913736 %
# For IMOEX ticker parsing. Currently parsed: 53.27476038338658 %
# For IMOEX ticker parsing. Currently parsed: 53.35463258785943 %
# For IMOEX ticker parsing. Currently parsed: 53.43450479233227 %
# For IMOEX ticker parsing. Currently parsed: 53.51437699680511 %
# For IMOEX ticker parsing. Currently parsed: 53.594249201277954 %
# For IMOEX ticker parsing. Currently parsed: 53.674121405750796 %
# For IMOEX ticker parsing. Currently parsed: 53.75399361022364 %
# For IMOEX ticker parsing. Currently parsed: 53.833865814696495 %
# For IMOEX ticker parsing. Currently parsed: 53.91373801916933 %
# For IMOEX ticker parsing. Currently parsed: 53.99361022364217 %
# For IMOEX ticker parsing. Currently parsed: 54.073482428115014 %
# For IMOEX ticker parsing. Currently parsed: 54.153354632587856 %
# For IMOEX ticker parsing. Currently parsed: 54.2332268370607 %
# For IMOEX ticker parsing. Currently parsed: 54.31309904153354 %
# For IMOEX ticker parsing. Currently parsed: 54.3929712460064 %
# For IMOEX ticker parsing. Currently parsed: 54.47284345047924 %
# For IMOEX ticker parsing. Currently parsed: 54.55271565495208 %
# For IMOEX ticker parsing. Currently parsed: 54.632587859424916 %
# For IMOEX ticker parsing. Currently parsed: 54.71246006389776 %
# For IMOEX ticker parsing. Currently parsed: 54.7923322683706 %
# For IMOEX ticker parsing. Currently parsed: 54.87220447284346 %
# For IMOEX ticker parsing. Currently parsed: 54.9520766773163 %
# For IMOEX ticker parsing. Currently parsed: 55.03194888178914 %
# For IMOEX ticker parsing. Currently parsed: 55.11182108626198 %
# For IMOEX ticker parsing. Currently parsed: 55.191693290734825 %
# For IMOEX ticker parsing. Currently parsed: 55.27156549520767 %
# For IMOEX ticker parsing. Currently parsed: 55.3514376996805 %
# For IMOEX ticker parsing. Currently parsed: 55.43130990415336 %
# For IMOEX ticker parsing. Currently parsed: 55.5111821086262 %
# For IMOEX ticker parsing. Currently parsed: 55.59105431309904 %
# For IMOEX ticker parsing. Currently parsed: 55.670926517571885 %
# For IMOEX ticker parsing. Currently parsed: 55.75079872204473 %
# For IMOEX ticker parsing. Currently parsed: 55.83067092651757 %
# For IMOEX ticker parsing. Currently parsed: 55.91054313099042 %
# For IMOEX ticker parsing. Currently parsed: 55.99041533546326 %
# For IMOEX ticker parsing. Currently parsed: 56.0702875399361 %
# For IMOEX ticker parsing. Currently parsed: 56.150159744408946 %
# For IMOEX ticker parsing. Currently parsed: 56.23003194888179 %
# For IMOEX ticker parsing. Currently parsed: 56.30990415335463 %
# ...
# For MOEXFN ticker parsing. Currently parsed: 80.38430744595676 %
# For MOEXFN ticker parsing. Currently parsed: 80.46437149719776 %
# For MOEXFN ticker parsing. Currently parsed: 80.54443554843876 %
# For MOEXFN ticker parsing. Currently parsed: 80.62449959967975 %
# For MOEXFN ticker parsing. Currently parsed: 80.70456365092073 %
# For MOEXFN ticker parsing. Currently parsed: 80.78462770216173 %
# For MOEXFN ticker parsing. Currently parsed: 80.86469175340272 %
# For MOEXFN ticker parsing. Currently parsed: 80.94475580464372 %
# For MOEXFN ticker parsing. Currently parsed: 81.02481985588472 %
# For MOEXFN ticker parsing. Currently parsed: 81.1048839071257 %
# For MOEXFN ticker parsing. Currently parsed: 81.18494795836669 %
# For MOEXFN ticker parsing. Currently parsed: 81.26501200960769 %
# For MOEXFN ticker parsing. Currently parsed: 81.34507606084867 %
# For MOEXFN ticker parsing. Currently parsed: 81.42514011208966 %
# For MOEXFN ticker parsing. Currently parsed: 81.50520416333067 %
# For MOEXFN ticker parsing. Currently parsed: 81.58526821457166 %
# For MOEXFN ticker parsing. Currently parsed: 81.66533226581265 %
# For MOEXFN ticker parsing. Currently parsed: 81.74539631705365 %
# For MOEXFN ticker parsing. Currently parsed: 81.82546036829463 %
# For MOEXFN ticker parsing. Currently parsed: 81.90552441953562 %
# For MOEXFN ticker parsing. Currently parsed: 81.98558847077662 %
# For MOEXFN ticker parsing. Currently parsed: 82.06565252201761 %
# For MOEXFN ticker parsing. Currently parsed: 82.14571657325861 %
# For MOEXFN ticker parsing. Currently parsed: 82.2257806244996 %
# For MOEXFN ticker parsing. Currently parsed: 82.30584467574059 %
# For MOEXFN ticker parsing. Currently parsed: 82.38590872698158 %
# For MOEXFN ticker parsing. Currently parsed: 82.46597277822258 %
# For MOEXFN ticker parsing. Currently parsed: 82.54603682946357 %
# For MOEXFN ticker parsing. Currently parsed: 82.62610088070457 %
# For MOEXFN ticker parsing. Currently parsed: 82.70616493194555 %
# For MOEXFN ticker parsing. Currently parsed: 82.78622898318655 %
# For MOEXFN ticker parsing. Currently parsed: 82.86629303442754 %
# For MOEXFN ticker parsing. Currently parsed: 82.94635708566854 %
# For MOEXFN ticker parsing. Currently parsed: 83.02642113690952 %
# For MOEXFN ticker parsing. Currently parsed: 83.10648518815053 %
# For MOEXFN ticker parsing. Currently parsed: 83.18654923939151 %
# For MOEXFN ticker parsing. Currently parsed: 83.2666132906325 %
# For MOEXFN ticker parsing. Currently parsed: 83.3466773418735 %
# For MOEXFN ticker parsing. Currently parsed: 83.42674139311448 %
# For MOEXFN ticker parsing. Currently parsed: 83.50680544435548 %
# For MOEXFN ticker parsing. Currently parsed: 83.58686949559647 %
# For MOEXFN ticker parsing. Currently parsed: 83.66693354683747 %
# For MOEXFN ticker parsing. Currently parsed: 83.74699759807847 %
# For MOEXFN ticker parsing. Currently parsed: 83.82706164931946 %
# For MOEXFN ticker parsing. Currently parsed: 83.90712570056044 %
# For MOEXFN ticker parsing. Currently parsed: 83.98718975180144 %
# For MOEXFN ticker parsing. Currently parsed: 84.06725380304243 %
# For MOEXFN ticker parsing. Currently parsed: 84.14731785428343 %
# For MOEXFN ticker parsing. Currently parsed: 84.22738190552442 %
# For MOEXFN ticker parsing. Currently parsed: 84.30744595676542 %
# For MOEXFN ticker parsing. Currently parsed: 84.3875100080064 %
# For MOEXFN ticker parsing. Currently parsed: 84.4675740592474 %
# For MOEXFN ticker parsing. Currently parsed: 84.54763811048839 %
# For MOEXFN ticker parsing. Currently parsed: 84.62770216172937 %
# For MOEXFN ticker parsing. Currently parsed: 84.70776621297038 %
# For MOEXFN ticker parsing. Currently parsed: 84.78783026421138 %
# For MOEXFN ticker parsing. Currently parsed: 84.86789431545236 %
# For MOEXFN ticker parsing. Currently parsed: 84.94795836669336 %
# For MOEXFN ticker parsing. Currently parsed: 85.02802241793435 %
# For MOEXFN ticker parsing. Currently parsed: 85.10808646917533 %
# For MOEXFN ticker parsing. Currently parsed: 85.18815052041633 %
# For MOEXFN ticker parsing. Currently parsed: 85.26821457165732 %
# For MOEXFN ticker parsing. Currently parsed: 85.34827862289832 %
# For MOEXFN ticker parsing. Currently parsed: 85.42834267413932 %
# For MOEXFN ticker parsing. Currently parsed: 85.5084067253803 %
# For MOEXFN ticker parsing. Currently parsed: 85.58847077662129 %
# For MOEXFN ticker parsing. Currently parsed: 85.66853482786229 %
# For MOEXFN ticker parsing. Currently parsed: 85.74859887910328 %
# For MOEXFN ticker parsing. Currently parsed: 85.82866293034428 %
# For MOEXFN ticker parsing. Currently parsed: 85.90872698158527 %
# For MOEXFN ticker parsing. Currently parsed: 85.98879103282626 %
# For MOEXFN ticker parsing. Currently parsed: 86.06885508406725 %
# For MOEXFN ticker parsing. Currently parsed: 86.14891913530825 %
# For MOEXFN ticker parsing. Currently parsed: 86.22898318654923 %
# For MOEXFN ticker parsing. Currently parsed: 86.30904723779024 %
# For MOEXFN ticker parsing. Currently parsed: 86.38911128903123 %
# For MOEXFN ticker parsing. Currently parsed: 86.46917534027222 %
# For MOEXFN ticker parsing. Currently parsed: 86.54923939151321 %
# For MOEXFN ticker parsing. Currently parsed: 86.6293034427542 %
# For MOEXFN ticker parsing. Currently parsed: 86.70936749399519 %
# For MOEXFN ticker parsing. Currently parsed: 86.78943154523618 %
# For MOEXFN ticker parsing. Currently parsed: 86.86949559647718 %
# For MOEXFN ticker parsing. Currently parsed: 86.94955964771817 %
# For MOEXFN ticker parsing. Currently parsed: 87.02962369895917 %
# For MOEXFN ticker parsing. Currently parsed: 87.10968775020017 %
# For MOEXFN ticker parsing. Currently parsed: 87.18975180144115 %
# For MOEXFN ticker parsing. Currently parsed: 87.26981585268214 %
# For MOEXFN ticker parsing. Currently parsed: 87.34987990392314 %
# For MOEXFN ticker parsing. Currently parsed: 87.42994395516413 %
# For MOEXFN ticker parsing. Currently parsed: 87.51000800640513 %
# For MOEXFN ticker parsing. Currently parsed: 87.59007205764611 %
# For MOEXFN ticker parsing. Currently parsed: 87.6701361088871 %
# For MOEXFN ticker parsing. Currently parsed: 87.7502001601281 %
# For MOEXFN ticker parsing. Currently parsed: 87.8302642113691 %
# For MOEXFN ticker parsing. Currently parsed: 87.9103282626101 %
# For MOEXFN ticker parsing. Currently parsed: 87.99039231385109 %
# For MOEXFN ticker parsing. Currently parsed: 88.07045636509207 %
# For MOEXFN ticker parsing. Currently parsed: 88.15052041633307 %
# For MOEXFN ticker parsing. Currently parsed: 88.23058446757406 %
# For MOEXFN ticker parsing. Currently parsed: 88.31064851881504 %
# For MOEXFN ticker parsing. Currently parsed: 88.39071257005604 %
# For MOEXFN ticker parsing. Currently parsed: 88.47077662129705 %
# For MOEXFN ticker parsing. Currently parsed: 88.55084067253803 %
# For MOEXFN ticker parsing. Currently parsed: 88.63090472377903 %
# For MOEXFN ticker parsing. Currently parsed: 88.71096877502002 %
# For MOEXFN ticker parsing. Currently parsed: 88.791032826261 %
# For MOEXFN ticker parsing. Currently parsed: 88.871096877502 %
# For MOEXFN ticker parsing. Currently parsed: 88.951160928743 %
# For MOEXFN ticker parsing. Currently parsed: 89.03122497998399 %
# For MOEXFN ticker parsing. Currently parsed: 89.11128903122498 %
# For MOEXFN ticker parsing. Currently parsed: 89.19135308246598 %
# For MOEXFN ticker parsing. Currently parsed: 89.27141713370696 %
# For MOEXFN ticker parsing. Currently parsed: 89.35148118494796 %
# For MOEXFN ticker parsing. Currently parsed: 89.43154523618895 %
# For MOEXFN ticker parsing. Currently parsed: 89.51160928742993 %
# For MOEXFN ticker parsing. Currently parsed: 89.59167333867094 %
# For MOEXFN ticker parsing. Currently parsed: 89.67173738991193 %
# For MOEXFN ticker parsing. Currently parsed: 89.75180144115292 %
# For MOEXFN ticker parsing. Currently parsed: 89.83186549239392 %
# For MOEXFN ticker parsing. Currently parsed: 89.91192954363491 %
# For MOEXFN ticker parsing. Currently parsed: 89.9919935948759 %
# For MOEXFN ticker parsing. Currently parsed: 90.0720576461169 %
# For MOEXFN ticker parsing. Currently parsed: 90.15212169735788 %
# For MOEXFN ticker parsing. Currently parsed: 90.23218574859888 %
# For MOEXFN ticker parsing. Currently parsed: 90.31224979983988 %
# For MOEXFN ticker parsing. Currently parsed: 90.39231385108086 %
# For MOEXFN ticker parsing. Currently parsed: 90.47237790232185 %
# For MOEXFN ticker parsing. Currently parsed: 90.55244195356285 %
# For MOEXFN ticker parsing. Currently parsed: 90.63250600480384 %
# For MOEXFN ticker parsing. Currently parsed: 90.71257005604484 %
# For MOEXFN ticker parsing. Currently parsed: 90.79263410728583 %
# For MOEXFN ticker parsing. Currently parsed: 90.87269815852682 %
# For MOEXFN ticker parsing. Currently parsed: 90.95276220976781 %
# For MOEXFN ticker parsing. Currently parsed: 91.03282626100881 %
# For MOEXFN ticker parsing. Currently parsed: 91.11289031224979 %
# For MOEXFN ticker parsing. Currently parsed: 91.1929543634908 %
# For MOEXFN ticker parsing. Currently parsed: 91.2730184147318 %
# For MOEXFN ticker parsing. Currently parsed: 91.35308246597278 %
# For MOEXFN ticker parsing. Currently parsed: 91.43314651721377 %
# For MOEXFN ticker parsing. Currently parsed: 91.51321056845477 %
# For MOEXFN ticker parsing. Currently parsed: 91.59327461969575 %
# For MOEXFN ticker parsing. Currently parsed: 91.67333867093676 %
# For MOEXFN ticker parsing. Currently parsed: 91.75340272217774 %
# For MOEXFN ticker parsing. Currently parsed: 91.83346677341873 %
# For MOEXFN ticker parsing. Currently parsed: 91.91353082465973 %
# For MOEXFN ticker parsing. Currently parsed: 91.99359487590073 %
# For MOEXFN ticker parsing. Currently parsed: 92.07365892714171 %
# For MOEXFN ticker parsing. Currently parsed: 92.1537229783827 %
# For MOEXFN ticker parsing. Currently parsed: 92.2337870296237 %
# For MOEXFN ticker parsing. Currently parsed: 92.3138510808647 %
# For MOEXFN ticker parsing. Currently parsed: 92.39391513210569 %
# For MOEXFN ticker parsing. Currently parsed: 92.47397918334667 %
# For MOEXFN ticker parsing. Currently parsed: 92.55404323458767 %
# For MOEXFN ticker parsing. Currently parsed: 92.63410728582866 %
# For MOEXFN ticker parsing. Currently parsed: 92.71417133706964 %
# For MOEXFN ticker parsing. Currently parsed: 92.79423538831065 %
# For MOEXFN ticker parsing. Currently parsed: 92.87429943955165 %
# For MOEXFN ticker parsing. Currently parsed: 92.95436349079263 %
# For MOEXFN ticker parsing. Currently parsed: 93.03442754203363 %
# For MOEXFN ticker parsing. Currently parsed: 93.11449159327462 %
# For MOEXFN ticker parsing. Currently parsed: 93.1945556445156 %
# For MOEXFN ticker parsing. Currently parsed: 93.2746196957566 %
# For MOEXFN ticker parsing. Currently parsed: 93.35468374699761 %
# For MOEXFN ticker parsing. Currently parsed: 93.43474779823859 %
# For MOEXFN ticker parsing. Currently parsed: 93.51481184947959 %
# For MOEXFN ticker parsing. Currently parsed: 93.59487590072058 %
# For MOEXFN ticker parsing. Currently parsed: 93.67493995196156 %
# For MOEXFN ticker parsing. Currently parsed: 93.75500400320256 %
# For MOEXFN ticker parsing. Currently parsed: 93.83506805444355 %
# For MOEXFN ticker parsing. Currently parsed: 93.91513210568455 %
# For MOEXFN ticker parsing. Currently parsed: 93.99519615692554 %
# For MOEXFN ticker parsing. Currently parsed: 94.07526020816654 %
# For MOEXFN ticker parsing. Currently parsed: 94.15532425940752 %
# For MOEXFN ticker parsing. Currently parsed: 94.23538831064852 %
# For MOEXFN ticker parsing. Currently parsed: 94.31545236188951 %
# For MOEXFN ticker parsing. Currently parsed: 94.39551641313051 %
# For MOEXFN ticker parsing. Currently parsed: 94.4755804643715 %
# For MOEXFN ticker parsing. Currently parsed: 94.55564451561249 %
# For MOEXFN ticker parsing. Currently parsed: 94.63570856685348 %
# For MOEXFN ticker parsing. Currently parsed: 94.71577261809448 %
# For MOEXFN ticker parsing. Currently parsed: 94.79583666933547 %
# For MOEXFN ticker parsing. Currently parsed: 94.87590072057645 %
# For MOEXFN ticker parsing. Currently parsed: 94.95596477181746 %
# For MOEXFN ticker parsing. Currently parsed: 95.03602882305844 %
# For MOEXFN ticker parsing. Currently parsed: 95.11609287429944 %
# For MOEXFN ticker parsing. Currently parsed: 95.19615692554044 %
# For MOEXFN ticker parsing. Currently parsed: 95.27622097678142 %
# For MOEXFN ticker parsing. Currently parsed: 95.35628502802241 %
# For MOEXFN ticker parsing. Currently parsed: 95.43634907926342 %
# For MOEXFN ticker parsing. Currently parsed: 95.5164131305044 %
# For MOEXFN ticker parsing. Currently parsed: 95.5964771817454 %
# For MOEXFN ticker parsing. Currently parsed: 95.6765412329864 %
# For MOEXFN ticker parsing. Currently parsed: 95.75660528422738 %
# For MOEXFN ticker parsing. Currently parsed: 95.83666933546837 %
# For MOEXFN ticker parsing. Currently parsed: 95.91673338670937 %
# For MOEXFN ticker parsing. Currently parsed: 95.99679743795036 %
# For MOEXFN ticker parsing. Currently parsed: 96.07686148919136 %
# For MOEXFN ticker parsing. Currently parsed: 96.15692554043235 %
# For MOEXFN ticker parsing. Currently parsed: 96.23698959167334 %
# For MOEXFN ticker parsing. Currently parsed: 96.31705364291433 %
# For MOEXFN ticker parsing. Currently parsed: 96.39711769415533 %
# For MOEXFN ticker parsing. Currently parsed: 96.47718174539631 %
# For MOEXFN ticker parsing. Currently parsed: 96.55724579663732 %
# For MOEXFN ticker parsing. Currently parsed: 96.6373098478783 %
# For MOEXFN ticker parsing. Currently parsed: 96.7173738991193 %
# For MOEXFN ticker parsing. Currently parsed: 96.79743795036029 %
# For MOEXFN ticker parsing. Currently parsed: 96.87750200160127 %
# For MOEXFN ticker parsing. Currently parsed: 96.95756605284227 %
# For MOEXFN ticker parsing. Currently parsed: 97.03763010408326 %
# For MOEXFN ticker parsing. Currently parsed: 97.11769415532426 %
# For MOEXFN ticker parsing. Currently parsed: 97.19775820656525 %
# For MOEXFN ticker parsing. Currently parsed: 97.27782225780625 %
# For MOEXFN ticker parsing. Currently parsed: 97.35788630904723 %
# For MOEXFN ticker parsing. Currently parsed: 97.43795036028823 %
# For MOEXFN ticker parsing. Currently parsed: 97.51801441152922 %
# For MOEXFN ticker parsing. Currently parsed: 97.59807846277022 %
# For MOEXFN ticker parsing. Currently parsed: 97.67814251401121 %
# For MOEXFN ticker parsing. Currently parsed: 97.75820656525221 %
# For MOEXFN ticker parsing. Currently parsed: 97.83827061649319 %
# For MOEXFN ticker parsing. Currently parsed: 97.91833466773419 %
# For MOEXFN ticker parsing. Currently parsed: 97.99839871897518 %
# For MOEXFN ticker parsing. Currently parsed: 98.07846277021616 %
# For MOEXFN ticker parsing. Currently parsed: 98.15852682145717 %
# For MOEXFN ticker parsing. Currently parsed: 98.23859087269817 %
# For MOEXFN ticker parsing. Currently parsed: 98.31865492393915 %
# For MOEXFN ticker parsing. Currently parsed: 98.39871897518015 %
# For MOEXFN ticker parsing. Currently parsed: 98.47878302642114 %
# For MOEXFN ticker parsing. Currently parsed: 98.55884707766212 %
# For MOEXFN ticker parsing. Currently parsed: 98.63891112890312 %
# For MOEXFN ticker parsing. Currently parsed: 98.71897518014411 %
# For MOEXFN ticker parsing. Currently parsed: 98.79903923138511 %
# For MOEXFN ticker parsing. Currently parsed: 98.8791032826261 %
# For MOEXFN ticker parsing. Currently parsed: 98.9591673338671 %
# For MOEXFN ticker parsing. Currently parsed: 99.03923138510808 %
# For MOEXFN ticker parsing. Currently parsed: 99.11929543634908 %
# For MOEXFN ticker parsing. Currently parsed: 99.19935948759007 %
# For MOEXFN ticker parsing. Currently parsed: 99.27942353883107 %
# For MOEXFN ticker parsing. Currently parsed: 99.35948759007206 %
# For MOEXFN ticker parsing. Currently parsed: 99.43955164131305 %
# For MOEXFN ticker parsing. Currently parsed: 99.51961569255404 %
# For MOEXFN ticker parsing. Currently parsed: 99.59967974379504 %
# For MOEXFN ticker parsing. Currently parsed: 99.67974379503602 %
# For MOEXFN ticker parsing. Currently parsed: 99.75980784627703 %
# For MOEXFN ticker parsing. Currently parsed: 99.83987189751802 %
# For MOEXFN ticker parsing. Currently parsed: 99.919935948759 %
# For MOEXFN ticker parsing. Currently parsed: 100.0 %

# %%
# resampling to monthly frequency stocks data
monthly_df_list_stocks = []
for ticker in TICKs:
    # filtering data for the current ticker
    ticker_data = combined_data[combined_data['STOCK_TICK'] == ticker]
  
    # setting 'begin' as datetime index for resampling
    ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
    ticker_data.set_index('begin', inplace=True)
    
    # resampling to monthly frequency
    monthly_df = ticker_data.resample('ME').agg({
        'open': 'first',
        'close': 'last', 
        'high': 'max',
        'low': 'min',
        'value': 'sum',
        'volume': 'sum',
        'STOCK_TICK': lambda x: ticker,
        'period': lambda x: 'M'
    })
    monthly_df.reset_index(inplace=True)
    monthly_df_list_stocks.append(monthly_df)

# combining all monthly data
fin_stock_data = pd.concat(monthly_df_list_stocks)

# combining with original daily data
combined_data['begin'] = combined_data['begin'].astype(str)
fin_stock_data['begin'] = fin_stock_data['begin'].astype(str)
final_combined_data = pd.concat([combined_data, fin_stock_data])
final_combined_data.to_json("Database/combined_data_stock.json", orient='records', lines=True)
final_combined_data
# Out:
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/811505522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
#          begin    open    close     high     low         value   volume  \
# 0   2020-03-31   389.9   390.00   390.00   386.3  6.398647e+07   164340
# 1   2020-04-01   388.3   385.00   389.90   385.0  2.024915e+07    52170
# 2   2020-04-02   389.3   371.50   389.90   368.6  9.524656e+07   252420
# 3   2020-04-03   369.9   365.10   373.80   365.1  5.497840e+07   149160
# 4   2020-04-06   368.7   366.90   370.80   365.0  4.776447e+07   130190
# ..         ...     ...      ...      ...     ...           ...      ...
# 56  2024-11-30  1473.0  1412.45  1548.95  1390.0  6.113613e+10  4201198
# 57  2024-12-31  1412.5  1398.10  1515.90  1305.0  5.650342e+10  4024599
# 58  2025-01-31  1405.0  1717.00  1743.80  1398.8  5.846154e+10  3639624
# 59  2025-02-28  1713.0  1931.30  1985.35  1655.2  8.046951e+10  4329115
# 60  2025-03-31  1931.3  1860.20  1987.50  1830.0  5.092184e+10  5581004
#
#    STOCK_TICK period
# 0        MVID      D
# 1        MVID      D
# 2        MVID      D
# 3        MVID      D
# 4        MVID      D
# ..        ...    ...
# 56       PLZL      M
# 57       PLZL      M
# 58       PLZL      M
# 59       PLZL      M
# 60       PLZL      M
#
# [49897 rows x 9 columns]

# %%
# resampling to monthly frequency indexes data
monthly_df_list_indexes = []
for ticker in TICK2s:
    # filtering data for the current ticker
    ticker_data = combined_data_index[combined_data_index['INDEX_TICK'] == ticker]
    if isinstance(ticker_data.index, pd.DatetimeIndex):
        ticker_data.reset_index(inplace=True)  # moving date index to column 'begin'
    
    # setting 'begin' as datetime index for resampling
    ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
    ticker_data.set_index('begin', inplace=True)
    
    # resampling to monthly frequency
    monthly_df = ticker_data.resample('ME').agg({
        'open': 'first',
        'close': 'last', 
        'high': 'max',
        'low': 'min',
        'value': 'sum',
        'tickers': 'first', 
        'INDEX_TICK': lambda x: ticker,
        'period': lambda x: 'M'
    })
    monthly_df.reset_index(inplace=True)
    monthly_df_list_indexes.append(monthly_df)

# combining all monthly data
fin_index_data = pd.concat(monthly_df_list_indexes)

# combining with original daily data
combined_data_index['begin'] = combined_data_index['begin'].astype(str)
fin_index_data['begin'] = fin_index_data['begin'].astype(str)
final_combined_data_index = pd.concat([combined_data_index, fin_index_data])
final_combined_data_index.to_json("Database/combined_data_index.json", orient='records', lines=True)
final_combined_data_index
# Out:
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/2730218808.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/2730218808.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/2730218808.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/2730218808.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/2730218808.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/2730218808.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/2730218808.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/2730218808.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/2730218808.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_5594/2730218808.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['begin'] = pd.to_datetime(ticker_data['begin'])
#          begin      open     close      high       low         value  \
# 0   2020-03-31   2466.28   2508.81   2526.13   2459.19  1.137560e+11
# 1   2020-04-01   2465.56   2473.61   2491.66   2449.01  8.025614e+10
# 2   2020-04-02   2528.72   2545.95   2562.54   2470.85  1.342401e+11
# 3   2020-04-03   2547.15   2572.23   2609.16   2533.06  1.171090e+11
# 4   2020-04-06   2597.28   2622.59   2639.56   2576.28  8.982314e+10
# ..         ...       ...       ...       ...       ...           ...
# 56  2024-11-30   8474.52   8707.29   9431.48   8198.45  7.276725e+11
# 57  2024-12-31   8691.27   9980.35   9980.35   8217.58  8.630320e+11
# 58  2025-01-31  10054.27  10250.10  10500.66   9691.62  6.314465e+11
# 59  2025-02-28  10207.07  11177.56  11726.61   9972.30  7.774956e+11
# 60  2025-03-31  11113.18  10772.65  11847.71  10643.27  6.561434e+11
#
#                                               tickers INDEX_TICK period
# 0   {PLZL, LKOH, CBOM, IRAO, HYDR, ROSN, DSKY, UPR...      IMOEX      D
# 1   {PLZL, LKOH, CBOM, IRAO, HYDR, ROSN, DSKY, UPR...      IMOEX      D
# 2   {PLZL, LKOH, CBOM, IRAO, HYDR, ROSN, DSKY, UPR...      IMOEX      D
# 3   {PLZL, LKOH, CBOM, IRAO, HYDR, ROSN, DSKY, UPR...      IMOEX      D
# 4   {PLZL, LKOH, CBOM, IRAO, HYDR, ROSN, DSKY, UPR...      IMOEX      D
# ..                                                ...        ...    ...
# 56  {SBER, RENI, VTBR, LEAS, BSPB, ZAYM, CBOM, SBE...     MOEXFN      M
# 57  {SBER, RENI, LEAS, BSPB, ZAYM, CBOM, SBERP, MO...     MOEXFN      M
# 58  {SBER, RENI, SPBE, LEAS, BSPB, ZAYM, CBOM, SBE...     MOEXFN      M
# 59  {SBER, RENI, SPBE, LEAS, BSPB, ZAYM, CBOM, SBE...     MOEXFN      M
# 60  {SBER, RENI, SPBE, LEAS, BSPB, ZAYM, CBOM, SBE...     MOEXFN      M
#
# [12339 rows x 9 columns]

# %% [markdown]
# <h3><b>Parsing of dividends data for stocks</b></h3>

# %%
# the URLs for the API endpoint
url1 = "https://iss.moex.com/iss/securities/"
url2 = "/dividends.xml"

# opening the txt file with the ticker names of necessary companies
with open("TICK_DIV.txt", "r") as TICK3s_file:
    TICK3s = [line.rstrip() for line in TICK3s_file]

# empty list to collect DataFrames
div_data = []
process3 = 0

# parsing process of dividends data
for i in range(len(TICK3s)):
    process3 += 1
    print(f"Parsing dividends data for the necessary tickers {(process3 / len(TICK3s)) * 100} %")
    response = requests.get(url1 + TICK3s[i] + url2)

    # parsing in case of success
    if response.status_code == 200:
        xml_data = response.content
        xml_string = xml_data.decode('utf-8')
        root = ET.fromstring(xml_string)

        for row in root.findall('.//row'):
            registry_closed_date = row.attrib.get('registryclosedate')
            # constraints on the necessary data format/values
            if registry_closed_date and int(registry_closed_date[0:4]) >= 2019 and int(registry_closed_date[0:4]) <= 2025:
                # a tuple to represent the unique entry
                unique_entry = row.attrib
                # appending the DataFrame to the list
                div_data.append(unique_entry)
                    
    # in case of fail
    else:
        print(f"Failed to retrieve data, status code: {response.status_code}")

# converting to DataFrame
df = pd.DataFrame(div_data)
df.rename(columns={'secid': 'DIV_TICK'}, inplace=True)

# converting the DataFrame to a JSON string
json_data = df.to_json("Database/combined_data_dividends.json", orient='records', lines=True)
# Out:
# Parsing dividends data for the necessary tickers 2.631578947368421 %
# Parsing dividends data for the necessary tickers 5.263157894736842 %
# Parsing dividends data for the necessary tickers 7.894736842105263 %
# Parsing dividends data for the necessary tickers 10.526315789473683 %
# Parsing dividends data for the necessary tickers 13.157894736842104 %
# Parsing dividends data for the necessary tickers 15.789473684210526 %
# Parsing dividends data for the necessary tickers 18.421052631578945 %
# Parsing dividends data for the necessary tickers 21.052631578947366 %
# Parsing dividends data for the necessary tickers 23.684210526315788 %
# Parsing dividends data for the necessary tickers 26.31578947368421 %
# Parsing dividends data for the necessary tickers 28.947368421052634 %
# Parsing dividends data for the necessary tickers 31.57894736842105 %
# Parsing dividends data for the necessary tickers 34.21052631578947 %
# Parsing dividends data for the necessary tickers 36.84210526315789 %
# Parsing dividends data for the necessary tickers 39.473684210526315 %
# Parsing dividends data for the necessary tickers 42.10526315789473 %
# Parsing dividends data for the necessary tickers 44.73684210526316 %
# Parsing dividends data for the necessary tickers 47.368421052631575 %
# Parsing dividends data for the necessary tickers 50.0 %
# Parsing dividends data for the necessary tickers 52.63157894736842 %
# Parsing dividends data for the necessary tickers 55.26315789473685 %
# Parsing dividends data for the necessary tickers 57.89473684210527 %
# Parsing dividends data for the necessary tickers 60.526315789473685 %
# Parsing dividends data for the necessary tickers 63.1578947368421 %
# Parsing dividends data for the necessary tickers 65.78947368421053 %
# Parsing dividends data for the necessary tickers 68.42105263157895 %
# Parsing dividends data for the necessary tickers 71.05263157894737 %
# Parsing dividends data for the necessary tickers 73.68421052631578 %
# Parsing dividends data for the necessary tickers 76.31578947368422 %
# Parsing dividends data for the necessary tickers 78.94736842105263 %
# Parsing dividends data for the necessary tickers 81.57894736842105 %
# Parsing dividends data for the necessary tickers 84.21052631578947 %
# Parsing dividends data for the necessary tickers 86.8421052631579 %
# Parsing dividends data for the necessary tickers 89.47368421052632 %
# Parsing dividends data for the necessary tickers 92.10526315789474 %
# Parsing dividends data for the necessary tickers 94.73684210526315 %
# Parsing dividends data for the necessary tickers 97.36842105263158 %
# Parsing dividends data for the necessary tickers 100.0 %
